# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from scipy.sparse import find
import sys
import re

# %% [markdown]
# # Pre-processar csv

# %%
cards = pd.read_csv("./cards.csv")
urls = pd.read_csv("./CSV/CrawlerHeuristica.csv")

# %%
cards['mana'] = cards['mana'].apply(lambda mana: re.sub('[,\' \[\]]', '', 
                                                        mana.replace('White', 'w').replace('Blue', 'u')
                                        .replace('Green', 'g').replace('Red', 'r').replace('Black', 'b')
                                        .replace('Mana', '').replace('or', '/')).lower()
                    if type(mana) == type('') else '')

# %%
cards['desc'] = cards['desc'].apply(lambda d: d.strip() if type(d) == type('') else '')
cards['name'] = cards['name'].apply(lambda n: n.strip() if type(n) == type('') else '')
cards['type'] = cards['type'].apply(lambda t: t.strip() if type(t) == type('') else '')

# %%
cards['rarity'] = cards['rarity'].apply(lambda r: 'Rare' if r == 'R' else 'Common' if r == 'C' else
                                        'Uncommon' if r == 'U' else 'Mythic' if r == 'M' else 
                                          r if type(r) == type('') else '')

# %%
def get_link_by_tuple(site, idx):
    return list(urls[(urls['Número'] == int(idx)) & (urls['Site'] == site)]['Link'])[0]
cards['url'] = cards['url'].apply(lambda u: get_link_by_tuple(u.split('/')[3].split('.com')[0] + '.com', u.split('/')[3].split('.com')[1].split('.html')[0]))

# %% [markdown]
# # Start from Here

# %%
cards.to_csv('final_cards.csv')

# %%
cards = pd.read_csv("./final_cards.csv")

# %%
count_vect = CountVectorizer(analyzer = "word",
                                 tokenizer = None,    
                                 preprocessor = None,
                                 stop_words = None)

# %%
docs = cards['name']

# %%
words = count_vect.fit_transform(docs)

# %%
features = count_vect.get_feature_names()

# %%
row, column, values = find(words)
terms = list(zip(row, column, values))

# %%
idf = {}
for feature in features:
    idf[feature] = 0
for (_, c, v) in terms:
    idf[features[c]] = idf[features[c]] + v

# %%
def tf_function(lr, lf, lv, r, f, v):
    return [(r, v)]
def tf_idf_function(lr, lf, lv, r, f, v):
    return [(r, v/idf[f])]
def tf_compressed_function(lr, lf, lv, r, f, v):
    return [(r-lr, v)] if lf == f else [(r, v)]
def tf_idf_compressed_function(lr, lf, lv, r, f, v):
    return [(r-lr, v/idf[f])] if lf == f else [(r, v/idf[f])]

# %%
def create_inverse_index(function):
    inverse_index = {}

    lr = None
    lf = None
    lv = None
    for (r, c, v) in terms:
        f = features[c]
        value = function( lr, lf, lv, r, f, v )
        if f in inverse_index:
            inverse_index[f] = inverse_index[f] + value
        else:
            inverse_index[f] = value
        lr = r
        lf = f
        lv = v
    return inverse_index

        
inverse_index_tf = create_inverse_index(tf_function)
inverse_index_tf_idf = create_inverse_index(tf_idf_function)
inverse_index_tf_compressed = create_inverse_index(tf_compressed_function)
inverse_index_tf_idf_compressed = create_inverse_index(tf_idf_compressed_function)

# %%
inverse_index_tf_compressed
# Out:
# {'10th': [(901, 1), (2672, 1), (213, 1), (844, 1)],
#  '2007': [(3677, 1)],
#  '2008': [(3556, 1)],
#  '2010': [(2965, 1), (1639, 1)],
#  '2011': [(116, 1),
#   (108, 1),
#   (89, 1),
#   (970, 1),
#   (284, 1),
#   (1946, 1),
#   (367, 1),
#   (485, 1)],
#  '2012': [(916, 1),
#   (67, 1),
#   (1574, 1),
#   (208, 1),
#   (561, 1),
#   (649, 1),
#   (302, 1),
#   (46, 1),
#   (468, 1)],
#  '2013': [(253, 1),
#   (237, 1),
#   (88, 1),
#   (35, 1),
#   (117, 1),
#   (127, 1),
#   (461, 1),
#   (264, 1),
#   (30, 1),
#   (2, 1),
#   (131, 1),
#   (542, 1),
#   (67, 1),
#   (333, 1),
#   (11, 1),
#   (122, 1),
#   (548, 1),
#   (54, 1),
#   (824, 1),
#   (71, 1),
#   (11, 1)],
#  '2014': [(39, 1),
#   (209, 1),
#   (78, 1),
#   (333, 1),
#   (6, 1),
#   (75, 1),
#   (169, 1),
#   (97, 1),
#   (14, 1),
#   (241, 1),
#   (823, 1),
#   (78, 1),
#   (227, 1),
#   (737, 1),
#   (64, 1),
#   (227, 1),
#   (103, 1),
#   (211, 1),
#   (307, 1),
#   (274, 1)],
#  '2015': [(335, 1),
#   (48, 1),
#   (423, 1),
#   (19, 1),
#   (44, 1),
#   (106, 1),
#   (201, 1),
#   (1528, 1),
#   (57, 1),
#   (713, 1),
#   (10, 1),
#   (446, 1),
#   (333, 1)],
#  '2016': [(279, 1),
#   (1256, 1),
#   (559, 1),
#   (349, 1),
#   (411, 1),
#   (197, 1),
#   (443, 1),
#   (16, 1),
#   (7, 1),
#   (271, 1),
#   (900, 1)],
#  '2017': [(147, 1), (3603, 1), (696, 1)],
#  '2019': [(87, 1), (25, 1), (1000, 1), (3, 1), (248, 1)],
#  '2020': [(0, 1),
#   (22, 1),
#   (8, 1),
#   (11, 1),
#   (15, 1),
#   (3, 1),
#   (2, 1),
#   (17, 1),
#   (46, 1),
#   (16, 1),
#   (34, 1),
#   (21, 1),
#   (36, 1),
#   (6, 1),
#   (102, 1),
#   (17, 1),
#   (19, 1),
#   (6, 1),
#   (19, 1),
#   (9, 1),
#   (2, 1),
#   (2, 1),
#   (15, 1),
#   (13, 1),
#   (12, 1),
#   (24, 1),
#   (8, 1),
#   (7, 1),
#   (36, 1),
#   (20, 1),
#   (18, 1),
#   (4, 1),
#   (29, 1),
#   (18, 1),
#   (30, 1),
#   (5, 1),
#   (18, 1),
#   (20, 1),
#   (38, 1),
#   (31, 1),
#   (21, 1),
#   (13, 1),
#   (15, 1),
#   (18, 1),
#   (3, 1),
#   (20, 1),
#   (13, 1),
#   (6, 1),
#   (14, 1),
#   (107, 1),
#   (8, 1),
#   (39, 1),
#   (15, 1),
#   (21, 1),
#   (23, 1),
#   (6, 1),
#   (20, 1),
#   (34, 1),
#   (16, 1),
#   (6, 1),
#   (27, 1),
#   (20, 1),
#   (45, 1),
#   (5, 1),
#   (12, 1),
#   (7, 1),
#   (14, 1),
#   (6, 1),
#   (19, 1),
#   (2, 1),
#   (15, 1),
#   (13, 1),
#   (10, 1),
#   (16, 1),
#   (44, 1),
#   (36, 1),
#   (14, 1),
#   (19, 1),
#   (27, 1),
#   (25, 1),
#   (2, 1),
#   (32, 1),
#   (9, 1),
#   (29, 1),
#   (26, 1),
#   (20, 1),
#   (1, 1),
#   (13, 1),
#   (25, 1),
#   (20, 1),
#   (23, 1),
#   (8, 1),
#   (41, 1),
#   (4, 1),
#   (58, 1),
#   (42, 1),
#   (37, 1),
#   (5, 1),
#   (2, 1),
#   (34, 1),
#   (46, 1),
#   (11, 1),
#   (19, 1),
#   (35, 1),
#   (14, 1),
#   (30, 1),
#   (16, 1),
#   (20, 1),
#   (27, 1),
#   (17, 1),
#   (3, 1),
#   (14, 1),
#   (7, 1),
#   (23, 1),
#   (5, 1),
#   (12, 1),
#   (20, 1),
#   (16, 1),
#   (21, 1),
#   (15, 1),
#   (30, 1),
#   (10, 1),
#   (7, 1),
#   (12, 1),
#   (5, 1),
#   (20, 1),
#   (36, 1),
#   (19, 1),
#   (30, 1),
#   (19, 1),
#   (16, 1),
#   (7, 1),
#   (14, 1),
#   (27, 1),
#   (44, 1),
#   (9, 1),
#   (5, 1),
#   (18, 1),
#   (20, 1),
#   (13, 1),
#   (55, 1),
#   (8, 1),
#   (37, 1),
#   (15, 1),
#   (20, 1),
#   (15, 1),
#   (37, 1),
#   (2, 1),
#   (34, 1),
#   (9, 1),
#   (16, 1),
#   (2, 1),
#   (65, 1),
#   (27, 1),
#   (2, 1),
#   (61, 1),
#   (1, 1),
#   (14, 1),
#   (16, 1),
#   (49, 1),
#   (9, 1),
#   (16, 1),
#   (1, 1),
#   (18, 1),
#   (33, 1),
#   (2, 1),
#   (50, 1),
#   (11, 1),
#   (26, 1),
#   (3, 1),
#   (28, 1),
#   (11, 1),
#   (7, 1),
#   (29, 1),
#   (7, 1),
#   (34, 1),
#   (11, 1),
#   (21, 1),
#   (11, 1),
#   (16, 1),
#   (40, 1),
#   (15, 1),
#   (18, 1),
#   (7, 1),
#   (24, 1),
#   (4, 1),
#   (17, 1),
#   (4, 1),
#   (85, 1),
#   (39, 1),
#   (4, 1),
#   (8, 1),
#   (83, 1),
#   (8, 1),
#   (81, 1),
#   (22, 1),
#   (6, 1),
#   (64, 1),
#   (8, 1),
#   (16, 1),
#   (56, 1),
#   (6, 1),
#   (32, 1),
#   (2, 1),
#   (5, 1),
#   (4, 1),
#   (11, 1),
#   (12, 1),
#   (6, 1),
#   (1, 1),
#   (14, 1),
#   (15, 1),
#   (6, 1),
#   (12, 1),
#   (22, 1),
#   (19, 1),
#   (43, 1),
#   (24, 1),
#   (5, 1),
#   (2, 1),
#   (10, 1),
#   (14, 1),
#   (12, 1),
#   (6, 1),
#   (4, 1),
#   (25, 1),
#   (1, 1),
#   (26, 1),
#   (30, 1),
#   (12, 1),
#   (14, 1),
#   (15, 1),
#   (52, 1),
#   (17, 1),
#   (38, 1),
#   (70, 1),
#   (8, 1),
#   (12, 1),
#   (49, 1),
#   (41, 1),
#   (5, 1)],
#  '218': [(4483, 1)],
#  '4th': [(565, 1), (245, 1), (1053, 1), (278, 1), (204, 1), (441, 1)],
#  '5th': [(1017, 1),
#   (569, 1),
#   (939, 1),
#   (470, 1),
#   (31, 1),
#   (352, 1),
#   (371, 1),
#   (427, 1)],
#  '6th': [(1056, 1), (547, 1), (1290, 1), (926, 1)],
#  '7th': [(374, 1), (2055, 1), (1402, 1)],
#  '8th': [(3134, 1)],
#  '9th': [(3446, 1)],
#  '_________': [(1442, 1), (2496, 1), (124, 1), (710, 1)],
#  'abandon': [(2794, 1)],
#  'abandoned': [(3885, 1)],
#  'abbot': [(1890, 1), (2590, 1), (254, 1)],
#  'aberration': [(3791, 1)],
#  'abhorrent': [(2068, 1), (883, 1)],
#  'abnormal': [(2840, 1), (912, 1)],
#  'abolisher': [(1398, 1), (263, 1), (816, 1)],
#  'abominable': [(538, 1), (3491, 1)],
#  'abomination': [(138, 1), (956, 1)],
#  'abrade': [(560, 1)],
#  'abrupt': [(241, 1), (1755, 1), (877, 1), (432, 1)],
#  'absolution': [(1397, 1), (895, 1)],
#  'absorb': [(1663, 1), (1044, 1)],
#  'abundance': [(574, 1),
#   (472, 1),
#   (221, 1),
#   (810, 1),
#   (1253, 1),
#   (11, 1),
#   (313, 1),
#   (1193, 1)],
#  'abundant': [(484, 1), (3317, 1), (1003, 1)],
#  'abzan': [(2052, 1), (226, 1)],
#  'academy': [(161, 1), (2351, 1), (1613, 1), (442, 1)],
#  'acclaimed': [(1015, 1),
#   (717, 1),
#   (231, 1),
#   (601, 1),
#   (69, 1),
#   (100, 1),
#   (151, 1),
#   (444, 1),
#   (102, 1),
#   (387, 1),
#   (724, 1),
#   (288, 1)],
#  'accomplices': [(2150, 1)],
#  'accord': [(1190, 1), (613, 1), (1314, 1), (403, 1), (211, 1)],
#  'accorder': [(721, 1), (353, 1)],
#  'accumulated': [(1445, 1)],
#  'accursed': [(292, 1), (229, 1), (2276, 1), (1399, 1)],
#  'acidic': [(1854, 1),
#   (421, 1),
#   (736, 1),
#   (322, 1),
#   (171, 1),
#   (379, 1),
#   (168, 1),
#   (391, 1),
#   (453, 1)],
#  'acolyte': [(275, 1),
#   (198, 1),
#   (520, 1),
#   (885, 1),
#   (152, 1),
#   (760, 1),
#   (332, 1),
#   (289, 1),
#   (209, 1),
#   (144, 1),
#   (968, 1),
#   (117, 1)],
#  'acquire': [(4545, 1)],
#  'act': [(33, 1),
#   (713, 1),
#   (574, 1),
#   (32, 1),
#   (89, 1),
#   (256, 1),
#   (216, 1),
#   (384, 1),
#   (198, 1),
#   (56, 1),
#   (352, 1),
#   (26, 1),
#   (87, 1),
#   (335, 1),
#   (31, 1),
#   (324, 1),
#   (55, 1),
#   (83, 1),
#   (588, 1),
#   (95, 1),
#   (98, 1),
#   (262, 1),
#   (32, 1)],
#  'adaptation': [(875, 1), (2288, 1)],
#  'adaptive': [(1193, 1), (1179, 1), (1853, 1), (73, 1)],
#  'adarkar': [(1001, 1),
#   (417, 1),
#   (822, 1),
#   (655, 1),
#   (376, 1),
#   (557, 1),
#   (67, 1),
#   (183, 1),
#   (100, 1),
#   (191, 1)],
#  'adeliz': [(1542, 1)],
#  'adephage': [(3665, 1)],
#  'adept': [(39, 1),
#   (758, 1),
#   (151, 1),
#   (634, 1),
#   (694, 1),
#   (796, 1),
#   (363, 1),
#   (888, 1),
#   (324, 1)],
#  'admiral': [(1937, 1), (245, 1), (893, 1), (1020, 1)],
#  'admonition': [(3251, 1)],
#  'adnate': [(2900, 1)],
#  'adorned': [(1789, 1), (1307, 1)],
#  'adversary': [(112, 1), (641, 1), (97, 1), (2522, 1), (164, 1), (401, 1)],
#  'adverse': [(2774, 1), (1573, 1)],
#  'advocate': [(45, 1), (1377, 1)],
#  'advokist': [(2841, 1)],
#  'aegis': [(417, 1),
#   (101, 1),
#   (398, 1),
#   (67, 1),
#   (397, 1),
#   (396, 1),
#   (22, 1),
#   (11, 1),
#   (346, 1),
#   (1844, 1)],
#  'aeons': [(2745, 1)],
#  'aerial': [(718, 1),
#   (726, 1),
#   (75, 1),
#   (407, 1),
#   (106, 1),
#   (294, 1),
#   (240, 1),
#   (439, 1),
#   (273, 1),
#   (121, 1),
#   (181, 1),
#   (30, 1)],
#  'aerialist': [(118, 1), (977, 1), (67, 1), (112, 1), (1593, 1), (419, 1)],
#  'aeronaut': [(311, 1), (664, 1), (2387, 1), (379, 1), (636, 1)],
#  'aether': [(17, 1),
#   (248, 1),
#   (109, 1),
#   (423, 1),
#   (151, 1),
#   (113, 1),
#   (172, 1),
#   (139, 1),
#   (58, 1),
#   (60, 1),
#   (197, 1),
#   (41, 1),
#   (199, 1),
#   (135, 1),
#   (217, 1),
#   (184, 1),
#   (54, 1),
#   (83, 1),
#   (132, 1),
#   (38, 1),
#   (102, 1),
#   (110, 1),
#   (95, 1),
#   (107, 1),
#   (84, 1),
#   (167, 1),
#   (694, 1),
#   (211, 1),
#   (126, 1),
#   (155, 1),
#   (1, 1),
#   (25, 1),
#   (75, 1)],
#  'aetherflux': [(4014, 1)],
#  'aethergeode': [(4622, 1)],
#  'aethershield': [(3662, 1), (844, 1)],
#  'aethersphere': [(17, 1), (3303, 1)],
#  'aetherspouts': [(927, 1), (1881, 1)],
#  'aethersquall': [(1220, 1)],
#  'aetherstorm': [(4284, 1)],
#  'aethertide': [(4340, 1)],
#  'aetherwind': [(2062, 1)],
#  'aetherworks': [(1633, 1), (923, 1)],
#  'affliciton': [(909, 1)],
#  'afflict': [(978, 1), (507, 1)],
#  'after': [(113, 1), (444, 1), (1328, 1), (2839, 1)],
#  'age': [(653, 1), (2204, 1), (413, 1), (1097, 1), (16, 1)],
#  'agent': [(956, 1),
#   (125, 1),
#   (535, 1),
#   (230, 1),
#   (22, 1),
#   (214, 1),
#   (4, 1),
#   (228, 1),
#   (5, 1),
#   (102, 1),
#   (780, 1),
#   (93, 1),
#   (379, 1),
#   (137, 1),
#   (414, 1),
#   (385, 1),
#   (9, 1),
#   (249, 1)],
#  'ages': [(2109, 1)],
#  'aggravate': [(758, 1), (3079, 1)],
#  'aggressive': [(91, 1),
#   (78, 1),
#   (100, 1),
#   (28, 1),
#   (360, 1),
#   (954, 1),
#   (646, 1),
#   (314, 1),
#   (608, 1)],
#  'agonies': [(1730, 1), (1647, 1)],
#  'agonizing': [(1295, 1), (1706, 1), (1632, 1), (77, 1), (48, 1)],
#  'ahn': [(966, 1), (1870, 1)],
#  'aid': [(2982, 1), (364, 1), (734, 1), (33, 1)],
#  'ainok': [(289, 1)],
#  'air': [(280, 1),
#   (847, 1),
#   (76, 1),
#   (838, 1),
#   (698, 1),
#   (375, 1),
#   (98, 1),
#   (253, 1),
#   (126, 1),
#   (7, 1),
#   (270, 1),
#   (79, 1),
#   (71, 1),
#   (795, 1)],
#  'ajani': [(89, 1),
#   (23, 1),
#   (86, 1),
#   (40, 1),
#   (16, 1),
#   (18, 1),
#   (292, 1),
#   (14, 1),
#   (15, 1),
#   (36, 1),
#   (30, 1),
#   (94, 1),
#   (35, 1),
#   (62, 1),
#   (22, 1),
#   (124, 1),
#   (116, 1),
#   (102, 1),
#   (34, 1),
#   (21, 1),
#   (100, 1),
#   (14, 1),
#   (42, 1),
#   (39, 1),
#   (101, 1),
#   (61, 1),
#   (157, 1),
#   (14, 1),
#   (107, 1),
#   (52, 1),
#   (344, 1),
#   (21, 1),
#   (30, 1),
#   (94, 1),
#   (132, 1),
#   (51, 1),
#   (66, 1),
#   (154, 1),
#   (465, 1),
#   (59, 1),
#   (2, 1),
#   (148, 1),
#   (14, 1),
#   (15, 1),
#   (221, 1),
#   (11, 1),
#   (13, 1),
#   (105, 1),
#   (15, 1),
#   (39, 1),
#   (2, 1),
#   (34, 1),
#   (51, 1),
#   (139, 1),
#   (27, 1),
#   (9, 1),
#   (26, 1),
#   (131, 1),
#   (31, 1),
#   (16, 1),
#   (33, 1),
#   (15, 1),
#   (103, 1),
#   (7, 1),
#   (28, 1),
#   (33, 1),
#   (41, 1),
#   (41, 1),
#   (40, 1),
#   (115, 1)],
#  'akoum': [(35, 1),
#   (36, 1),
#   (1078, 1),
#   (1918, 1),
#   (62, 1),
#   (106, 1),
#   (1414, 1),
#   (144, 1)],
#  'akroan': [(2199, 1), (423, 1), (289, 1), (654, 1), (974, 1)],
#  'akroma': [(643, 1), (510, 1), (97, 1), (3308, 1)],
#  'akros': [(93, 1), (304, 1), (91, 1)],
#  'alabaster': [(1681, 1), (1196, 1), (192, 1), (1151, 1)],
#  'aladdin': [(80, 1),
#   (45, 1),
#   (241, 1),
#   (12, 1),
#   (25, 1),
#   (417, 1),
#   (34, 1),
#   (11, 1),
#   (37, 1),
#   (220, 1),
#   (35, 1),
#   (105, 1),
#   (42, 1),
#   (4, 1),
#   (291, 1),
#   (46, 1),
#   (431, 1),
#   (36, 1),
#   (279, 1),
#   (5, 1),
#   (30, 1),
#   (41, 1),
#   (224, 1),
#   (31, 1),
#   (252, 1),
#   (7, 1),
#   (33, 1),
#   (141, 1),
#   (38, 1),
#   (7, 1),
#   (258, 1),
#   (35, 1),
#   (421, 1),
#   (37, 1),
#   (13, 1),
#   (278, 1),
#   (34, 1),
#   (90, 1),
#   (38, 1),
#   (273, 1),
#   (14, 1),
#   (29, 1)],
#  'alara': [(170, 1), (685, 1), (1316, 1), (733, 1), (1012, 1), (49, 1)],
#  'alarm': [(2239, 1), (29, 1), (816, 1)],
#  'albino': [(4183, 1)],
#  'alchemist': [(591, 1), (50, 1), (1073, 1), (1536, 1), (917, 1), (308, 1)],
#  'alela': [(3596, 1)],
#  'alesha': [(4690, 1)],
#  'alexandria': [(153, 1),
#   (20, 1),
#   (427, 1),
#   (18, 1),
#   (432, 1),
#   (457, 1),
#   (309, 1),
#   (64, 1),
#   (308, 1),
#   (301, 1),
#   (1214, 1),
#   (347, 1),
#   (563, 1),
#   (154, 1)],
#  'alhammarret': [(765, 1),
#   (942, 1),
#   (281, 1),
#   (29, 1),
#   (117, 1),
#   (374, 1),
#   (2100, 1)],
#  'aligned': [(2928, 1), (1072, 1)],
#  'alin': [(3467, 1)],
#  'all': [(436, 1),
#   (25, 1),
#   (34, 1),
#   (125, 1),
#   (369, 1),
#   (120, 1),
#   (46, 1),
#   (261, 1),
#   (1888, 1),
#   (320, 1),
#   (19, 1),
#   (506, 1),
#   (201, 1)],
#  'allainces': [(2900, 1), (742, 1)],
#  'allegiance': [(1663, 1)],
#  'allergy': [(4391, 1)],
#  'alliance': [(190, 1), (992, 1)],
#  'alluring': [(9, 1), (336, 1), (693, 1), (1783, 1), (309, 1), (1295, 1)],
#  'ally': [(1683, 1), (1546, 1), (218, 1)],
#  'alpha': [(429, 1),
#   (220, 1),
#   (136, 1),
#   (146, 1),
#   (275, 1),
#   (196, 1),
#   (128, 1),
#   (301, 1),
#   (586, 1),
#   (129, 1),
#   (200, 1),
#   (252, 1),
#   (4, 1),
#   (30, 1),
#   (321, 1),
#   (219, 1),
#   (29, 1),
#   (67, 1),
#   (60, 1),
#   (164, 1),
#   (254, 1),
#   (257, 1),
#   (427, 1),
#   (80, 1)],
#  'alpine': [(877, 1), (1390, 1), (552, 1), (1633, 1)],
#  'altac': [(812, 1), (3059, 1)],
#  'altar': [(46, 1),
#   (305, 1),
#   (453, 1),
#   (631, 1),
#   (4, 1),
#   (327, 1),
#   (506, 1),
#   (170, 1),
#   (306, 1),
#   (307, 1),
#   (1393, 1),
#   (235, 1),
#   (34, 1)],
#  'always': [(3506, 1)],
#  'amalgam': [(543, 1)],
#  'amass': [(205, 1), (4384, 1)],
#  'ambassador': [(421, 1), (2015, 1), (2278, 1)],
#  'amber': [(4570, 1)],
#  'ambition': [(3863, 1)],
#  'ambusher': [(2831, 1), (512, 1), (202, 1)],
#  'amonkhet': [(1212, 1)],
#  'amorphous': [(3616, 1), (905, 1)],
#  'amphin': [(433, 1), (638, 1)],
#  'ampryn': [(184, 1), (3504, 1)],
#  'amulet': [(468, 1),
#   (137, 1),
#   (1068, 1),
#   (226, 1),
#   (1581, 1),
#   (21, 1),
#   (926, 1)],
#  'anathemancer': [(658, 1), (1678, 1), (568, 1), (288, 1)],
#  'ancestral': [(446, 1),
#   (163, 1),
#   (326, 1),
#   (2436, 1),
#   (788, 1),
#   (93, 1),
#   (348, 1)],
#  'ancestry': [(428, 1), (865, 1), (3130, 1)],
#  'anchor': [(1061, 1), (429, 1)],
#  'ancient': [(157, 1),
#   (197, 1),
#   (585, 1),
#   (281, 1),
#   (133, 1),
#   (895, 1),
#   (331, 1),
#   (276, 1),
#   (694, 1),
#   (498, 1),
#   (305, 1),
#   (30, 1),
#   (28, 1),
#   (43, 1)],
#  'ancients': [(170, 1), (3252, 1)],
#  'and': [(737, 1),
#   (1732, 1),
#   (184, 1),
#   (176, 1),
#   (510, 1),
#   (182, 1),
#   (315, 1),
#   (357, 1),
#   (460, 1),
#   (49, 1),
#   (226, 1)],
#  'angel': [(75, 1),
#   (1, 1),
#   (26, 1),
#   (86, 1),
#   (129, 1),
#   (64, 1),
#   (17, 1),
#   (19, 1),
#   (63, 1),
#   (121, 1),
#   (18, 1),
#   (155, 1),
#   (72, 1),
#   (66, 1),
#   (4, 1),
#   (67, 1),
#   (64, 1),
#   (87, 1),
#   (6, 1),
#   (2, 1),
#   (191, 1),
#   (6, 1),
#   (17, 1),
#   (24, 1),
#   (16, 1),
#   (58, 1),
#   (45, 1),
#   (22, 1),
#   (108, 1),
#   (26, 1),
#   (51, 1),
#   (9, 1),
#   (4, 1),
#   (75, 1),
#   (15, 1),
#   (176, 1),
#   (34, 1),
#   (81, 1),
#   (48, 1),
#   (16, 1),
#   (43, 1),
#   (14, 1),
#   (88, 1),
#   (56, 1),
#   (36, 1),
#   (17, 1),
#   (37, 1),
#   (35, 1),
#   (6, 1),
#   (9, 1),
#   (100, 1),
#   (36, 1),
#   (59, 1),
#   (56, 1),
#   (141, 1),
#   (62, 1),
#   (34, 1),
#   (130, 1),
#   (48, 1),
#   (80, 1),
#   (25, 1),
#   (13, 1),
#   (100, 1),
#   (60, 1),
#   (21, 1),
#   (15, 1),
#   (190, 1),
#   (9, 1),
#   (17, 1),
#   (3, 1),
#   (55, 1),
#   (97, 1),
#   (78, 1),
#   (65, 1),
#   (35, 1),
#   (7, 1),
#   (19, 1),
#   (146, 1),
#   (1, 1),
#   (51, 1),
#   (38, 1),
#   (9, 1),
#   (104, 1),
#   (143, 1),
#   (1, 1),
#   (53, 1),
#   (93, 1),
#   (13, 1),
#   (197, 1),
#   (20, 1)],
#  'angelic': [(224, 1),
#   (76, 1),
#   (96, 1),
#   (152, 1),
#   (119, 1),
#   (3, 1),
#   (198, 1),
#   (197, 1),
#   (151, 1),
#   (287, 1),
#   (10, 1),
#   (44, 1),
#   (246, 1),
#   (105, 1),
#   (58, 1),
#   (82, 1),
#   (2, 1),
#   (144, 1),
#   (23, 1),
#   (270, 1),
#   (430, 1),
#   (200, 1),
#   (259, 1),
#   (20, 1),
#   (14, 1),
#   (11, 1),
#   (95, 1),
#   (4, 1),
#   (196, 1),
#   (15, 1),
#   (120, 1),
#   (36, 1),
#   (214, 1),
#   (259, 1),
#   (20, 1)],
#  'anger': [(399, 1), (494, 1)],
#  'angler': [(1895, 1), (2840, 1)],
#  'angrath': [(2118, 1)],
#  'anguished': [(1660, 1)],
#  'anima': [(129, 1), (2042, 1), (1018, 1), (1207, 1)],
#  'animate': [(5, 1),
#   (48, 1),
#   (1, 1),
#   (79, 1),
#   (593, 1),
#   (364, 1),
#   (116, 1),
#   (3, 1),
#   (1092, 1),
#   (661, 1),
#   (186, 1),
#   (366, 1),
#   (383, 1),
#   (82, 1),
#   (211, 1),
#   (274, 1),
#   (173, 1),
#   (32, 1),
#   (75, 1)],
#  'animating': [(1770, 1), (11, 1), (2591, 1)],
#  'animist': [(66, 1), (230, 1), (292, 1), (136, 1), (4059, 1)],
#  'ankle': [(3438, 1)],
#  'annex': [(3428, 1)],
#  'anointer': [(500, 1), (138, 1)],
#  'answered': [(2554, 1), (1552, 1)],
#  'ant': [(2908, 1), (198, 1)],
#  'anthologies': [(3256, 1)],
#  'anthology': [(2205, 1), (205, 1), (2208, 1)],
#  'anticipate': [(360, 1),
#   (184, 1),
#   (399, 1),
#   (1370, 1),
#   (25, 1),
#   (403, 1),
#   (43, 1),
#   (1018, 1),
#   (466, 1),
#   (391, 1),
#   (117, 1)],
#  'anticipation': [(1792, 1), (909, 1), (576, 1), (1048, 1), (168, 1), (71, 1)],
#  'antiquities': [(2089, 1)],
#  'anvil': [(2650, 1)],
#  'anvilwrought': [(1401, 1), (849, 1), (1321, 1), (399, 1), (886, 1)],
#  'apex': [(100, 1), (176, 1), (610, 1), (128, 1), (3518, 1)],
#  'apocalypse': [(3307, 1)],
#  'apostle': [(78, 1), (153, 1), (585, 1), (637, 1), (1136, 1), (1899, 1)],
#  'appetite': [(2768, 1), (12, 1), (727, 1)],
#  'apprentice': [(641, 1), (584, 1), (559, 1), (2225, 1), (158, 1), (669, 1)],
#  'arachnus': [(391, 1), (449, 1), (2138, 1), (219, 1)],
#  'arashin': [(2101, 1), (346, 1)],
#  'arbalest': [(1280, 1), (356, 1)],
#  'arbiter': [(224, 1),
#   (195, 1),
#   (346, 1),
#   (451, 1),
#   (801, 1),
#   (76, 1),
#   (415, 1),
#   (1008, 1)],
#  'arbor': [(2502, 1), (942, 1), (825, 1), (217, 1)],
#  'arc': [(13, 1), (1239, 1), (1396, 1), (374, 1)],
#  'arcades': [(1363, 1), (197, 1), (277, 1), (1845, 1), (603, 1), (607, 1)],
#  'arcane': [(875, 1),
#   (588, 1),
#   (82, 1),
#   (311, 1),
#   (1307, 1),
#   (594, 1),
#   (112, 1),
#   (472, 1)],
#  'arcanist': [(77, 1)],
#  'arcbound': [(63, 1),
#   (214, 1),
#   (71, 1),
#   (326, 1),
#   (9, 1),
#   (497, 1),
#   (109, 1),
#   (135, 1),
#   (161, 1),
#   (343, 1),
#   (371, 1),
#   (117, 1),
#   (342, 1),
#   (75, 1),
#   (17, 1),
#   (283, 1),
#   (182, 1),
#   (29, 1),
#   (412, 1),
#   (1135, 1)],
#  'arch': [(1268, 1), (3087, 1)],
#  'archaeomancer': [(1124, 1), (1034, 1), (654, 1), (869, 1)],
#  'archangel': [(738, 1),
#   (843, 1),
#   (254, 1),
#   (181, 1),
#   (127, 1),
#   (290, 1),
#   (317, 1),
#   (70, 1),
#   (545, 1),
#   (406, 1),
#   (293, 1),
#   (125, 1),
#   (307, 1),
#   (32, 1)],
#  'archdruid': [(3657, 1)],
#  'archenemy': [(1391, 1)],
#  'archfiend': [(1212, 1), (3087, 1)],
#  'architect': [(2412, 1), (1676, 1), (427, 1)],
#  'architects': [(1644, 1), (2129, 1)],
#  'archive': [(1707, 1), (281, 1), (146, 1), (2474, 1)],
#  'archmage': [(699, 1), (1280, 1)],
#  'archon': [(1397, 1),
#   (426, 1),
#   (243, 1),
#   (226, 1),
#   (116, 1),
#   (22, 1),
#   (335, 1),
#   (252, 1),
#   (1866, 1)],
#  'archwing': [(3061, 1), (625, 1)],
#  'arclight': [(2255, 1)],
#  'arctic': [(127, 1), (1725, 1)],
#  'ardent': [(2073, 1), (900, 1)],
#  'ardenvale': [(1447, 1),
#   (391, 1),
#   (291, 1),
#   (496, 1),
#   (1239, 1),
#   (547, 1),
#   (381, 1)],
#  'arena': [(498, 1),
#   (754, 1),
#   (196, 1),
#   (1166, 1),
#   (366, 1),
#   (1511, 1),
#   (55, 1)],
#  'argothian': [(8, 1), (1615, 1)],
#  'arid': [(791, 1)],
#  'arisen': [(673, 1), (1539, 1), (1180, 1)],
#  'arkbow': [(1101, 1), (570, 1), (2096, 1)],
#  'arlinn': [(4463, 1)],
#  'armada': [(1472, 1), (404, 1)],
#  'armageddon': [(107, 1),
#   (489, 1),
#   (18, 1),
#   (532, 1),
#   (358, 1),
#   (633, 1),
#   (891, 1),
#   (104, 1),
#   (603, 1),
#   (39, 1),
#   (721, 1),
#   (375, 1),
#   (45, 1)],
#  'armaments': [(300, 1), (1203, 1), (2213, 1)],
#  'armies': [(2328, 1), (560, 1)],
#  'armor': [(232, 1),
#   (46, 1),
#   (784, 1),
#   (551, 1),
#   (133, 1),
#   (231, 1),
#   (477, 1),
#   (216, 1),
#   (510, 1),
#   (437, 1),
#   (35, 1),
#   (622, 1),
#   (636, 1)],
#  'armored': [(1567, 1), (799, 1), (719, 1), (199, 1), (1174, 1)],
#  'arms': [(223, 1),
#   (601, 1),
#   (89, 1),
#   (358, 1),
#   (133, 1),
#   (353, 1),
#   (82, 1),
#   (35, 1),
#   (197, 1),
#   (1505, 1),
#   (136, 1),
#   (519, 1),
#   (485, 1)],
#  'arrest': [(3199, 1)],
#  'arsenal': [(2, 1)],
#  'art': [(560, 1),
#   (455, 1),
#   (645, 1),
#   (129, 1),
#   (174, 1),
#   (1593, 1),
#   (121, 1)],
#  'artful': [(624, 1), (2268, 1), (704, 1), (13, 1)],
#  'artifact': [(1206, 1), (3169, 1)],
#  'artifice': [(1858, 1), (464, 1), (984, 1)],
#  'artificer': [(334, 1),
#   (301, 1),
#   (780, 1),
#   (1438, 1),
#   (809, 1),
#   (593, 1),
#   (175, 1),
#   (76, 1),
#   (86, 1),
#   (305, 1)],
#  'artisan': [(2560, 1), (777, 1), (282, 1), (905, 1), (62, 1)],
#  'artist': [(156, 1), (876, 1), (2154, 1)],
#  'as': [(2404, 1)],
#  'ascendancy': [(2052, 1)],
#  'ascendant': [(1638, 1), (1030, 1)],
#  'ascension': [(1567, 1),
#   (144, 1),
#   (103, 1),
#   (552, 1),
#   (719, 1),
#   (122, 1),
#   (77, 1),
#   (73, 1),
#   (1101, 1)],
#  'asceticism': [(3672, 1)],
#  'ash': [(392, 1),
#   (180, 1),
#   (82, 1),
#   (1218, 1),
#   (413, 1),
#   (92, 1),
#   (595, 1),
#   (414, 1)],
#  'ashes': [(2068, 1)],
#  'ashiok': [(1952, 1)],
#  'ashnod': [(804, 1), (3644, 1)],
#  'ashvale': [(2258, 1)],
#  'aspect': [(1131, 1), (1157, 1)],
#  'asphodel': [(1821, 1)],
#  'aspiring': [(311, 1), (4066, 1)],
#  'assassin': [(109, 1), (2836, 1), (554, 1)],
#  'assassinate': [(768, 1), (18, 1), (592, 1), (1070, 1)],
#  'assault': [(448, 1),
#   (16, 1),
#   (104, 1),
#   (316, 1),
#   (224, 1),
#   (336, 1),
#   (588, 1),
#   (6, 1),
#   (528, 1),
#   (439, 1),
#   (273, 1),
#   (121, 1),
#   (82, 1),
#   (99, 1),
#   (30, 1),
#   (212, 1),
#   (262, 1),
#   (491, 1),
#   (256, 1)],
#  'assembler': [(3534, 1)],
#  'asura': [(1103, 1)],
#  'at': [(1412, 1), (1246, 1), (1119, 1), (49, 1), (864, 1)],
#  'atarka': [(2823, 1)],
#  'atemsis': [(436, 1),
#   (59, 1),
#   (494, 1),
#   (120, 1),
#   (46, 1),
#   (2488, 1),
#   (506, 1)],
#  'athreos': [(2376, 1)],
#  'atlantis': [(876, 1),
#   (1470, 1),
#   (288, 1),
#   (907, 1),
#   (348, 1),
#   (230, 1),
#   (56, 1),
#   (272, 1)],
#  'attended': [(3118, 1), (791, 1)],
#  'audacious': [(1761, 1), (778, 1), (1311, 1), (383, 1), (180, 1), (361, 1)],
#  'augur': [(666, 1), (2390, 1), (140, 1)],
#  'augury': [(2337, 1), (2098, 1)],
#  'aura': [(3594, 1), (640, 1), (93, 1)],
#  'auramancer': [(271, 1), (117, 1), (516, 1), (666, 1), (721, 1), (1630, 1)],
#  'aurelia': [(423, 1), (2386, 1), (1115, 1)],
#  'auriok': [(845, 1), (147, 1), (203, 1), (2609, 1)],
#  'automaton': [(1193, 1), (1179, 1), (1853, 1), (73, 1)],
#  'autumn': [(801, 1), (554, 1), (767, 1), (2075, 1), (531, 1)],
#  'avacyn': [(300, 1),
#   (67, 1),
#   (924, 1),
#   (710, 1),
#   (18, 1),
#   (436, 1),
#   (50, 1),
#   (534, 1),
#   (84, 1),
#   (1066, 1),
#   (18, 1),
#   (291, 1),
#   (303, 1)],
#  'avarice': [(1673, 1), (1828, 1)],
#  'avaricious': [(837, 1), (205, 1)],
#  'avatar': [(1648, 1), (288, 1), (1189, 1), (100, 1), (913, 1)],
#  'aven': [(127, 1),
#   (75, 1),
#   (205, 1),
#   (145, 1),
#   (562, 1),
#   (164, 1),
#   (510, 1),
#   (64, 1),
#   (245, 1),
#   (52, 1),
#   (587, 1),
#   (241, 1),
#   (182, 1),
#   (77, 1),
#   (726, 1)],
#  'avenger': [(1336, 1), (640, 1), (311, 1), (67, 1), (1176, 1)],
#  'aviation': [(3433, 1), (1426, 1)],
#  'awake': [(3402, 1)],
#  'awaken': [(939, 1), (1640, 1)],
#  'awakened': [(2717, 1), (64, 1), (1000, 1), (379, 1), (281, 1), (444, 1)],
#  'awakener': [(237, 1),
#   (238, 1),
#   (522, 1),
#   (85, 1),
#   (172, 1),
#   (1073, 1),
#   (1226, 1)],
#  'awakening': [(588, 1), (315, 1), (2913, 1), (967, 1), (44, 1)],
#  'away': [(695, 1)],
#  'axe': [(3616, 1), (905, 1)],
#  'ayara': [(1371, 1), (2084, 1)],
#  'azcanta': [(4646, 1)],
#  'azorius': [(438, 1), (1502, 1), (518, 1), (1334, 1), (652, 1)],
#  'azure': [(167, 1), (656, 1), (805, 1), (1017, 1)],
#  'azusa': [(2000, 1), (970, 1), (1069, 1)],
#  'baan': [(3562, 1)],
#  'back': [(1136, 1),
#   (466, 1),
#   (444, 1),
#   (497, 1),
#   (126, 1),
#   (577, 1),
#   (403, 1),
#   (303, 1),
#   (370, 1)],
#  'badlands': [(123, 1),
#   (254, 1),
#   (35, 1),
#   (416, 1),
#   (36, 1),
#   (256, 1),
#   (155, 1),
#   (31, 1),
#   (182, 1),
#   (53, 1),
#   (663, 1),
#   (190, 1),
#   (46, 1),
#   (245, 1),
#   (766, 1),
#   (36, 1),
#   (355, 1),
#   (385, 1),
#   (46, 1),
#   (90, 1),
#   (26, 1)],
#  'bag': [(137, 1), (954, 1), (811, 1), (46, 1), (2261, 1), (186, 1), (335, 1)],
#  'bairn': [(3797, 1), (1056, 1)],
#  'bake': [(2352, 1)],
#  'bala': [(1982, 1), (986, 1)],
#  'balefire': [(460, 1)],
#  'ball': [(2715, 1), (506, 1)],
#  'ballard': [(3266, 1)],
#  'ballista': [(2943, 1)],
#  'baloth': [(665, 1), (701, 1), (72, 1), (656, 1)],
#  'baloths': [(1020, 1), (725, 1), (2066, 1)],
#  'balthor': [(686, 1), (3134, 1)],
#  'bane': [(1982, 1), (410, 1), (576, 1)],
#  'banefire': [(405, 1), (853, 1), (2547, 1)],
#  'baneslayer': [(398, 1),
#   (742, 1),
#   (515, 1),
#   (710, 1),
#   (594, 1),
#   (490, 1),
#   (36, 1),
#   (820, 1)],
#  'banish': [(2576, 1)],
#  'banisher': [(3599, 1), (501, 1)],
#  'banishing': [(1993, 1), (2003, 1)],
#  'banner': [(2506, 1)],
#  'banners': [(1722, 1), (2923, 1)],
#  'bant': [(117, 1), (25, 1), (3769, 1), (807, 1)],
#  'baral': [(136, 1), (1243, 1)],
#  'barbarian': [(1593, 1), (1337, 1)],
#  'barbed': [(553, 1), (3386, 1), (54, 1)],
#  'bard': [(2569, 1)],
#  'barge': [(4069, 1)],
#  'barghest': [(3637, 1)],
#  'barkhide': [(411, 1), (1388, 1), (484, 1), (1219, 1), (396, 1), (850, 1)],
#  'baron': [(1029, 1), (294, 1)],
#  'barony': [(826, 1), (2143, 1), (263, 1), (254, 1)],
#  'barrage': [(1351, 1), (1313, 1), (903, 1), (572, 1), (412, 1)],
#  'barrens': [(2468, 1), (2320, 1)],
#  'barrow': [(466, 1)],
#  'barter': [(32, 1), (3247, 1)],
#  'bartered': [(1055, 1), (2881, 1)],
#  'bartizan': [(1654, 1), (388, 1), (545, 1)],
#  'basandra': [(1920, 1)],
#  'bash': [(1409, 1), (1384, 1)],
#  'basilisk': [(284, 1),
#   (1531, 1),
#   (104, 1),
#   (448, 1),
#   (165, 1),
#   (117, 1),
#   (155, 1),
#   (554, 1),
#   (276, 1),
#   (117, 1),
#   (1135, 1)],
#  'basker': [(2062, 1)],
#  'bastion': [(2636, 1), (907, 1)],
#  'bat': [(2211, 1), (1792, 1)],
#  'bats': [(1654, 1), (388, 1), (545, 1)],
#  'battalion': [(1414, 1), (113, 1), (642, 1), (214, 1), (12, 1)],
#  'batterskull': [(2711, 1), (1667, 1)],
#  'battery': [(145, 1), (4597, 1)],
#  'battle': [(71, 1),
#   (131, 1),
#   (13, 1),
#   (24, 1),
#   (158, 1),
#   (91, 1),
#   (661, 1),
#   (42, 1),
#   (87, 1),
#   (233, 1),
#   (38, 1),
#   (371, 1),
#   (150, 1),
#   (35, 1),
#   (275, 1),
#   (315, 1),
#   (207, 1),
#   (35, 1),
#   (1146, 1),
#   (433, 1)],
#  'battlefield': [(802, 1),
#   (216, 1),
#   (310, 1),
#   (1014, 1),
#   (21, 1),
#   (43, 1),
#   (555, 1),
#   (1071, 1),
#   (771, 1),
#   (30, 1)],
#  'battleflight': [(1187, 1), (454, 1)],
#  'battleguard': [(2020, 1)],
#  'battlehorns': [(3621, 1)],
#  'battlesphere': [(4401, 1)],
#  'battlewise': [(3159, 1), (803, 1)],
#  'bayou': [(72, 1),
#   (38, 1),
#   (89, 1),
#   (550, 1),
#   (292, 1),
#   (69, 1),
#   (484, 1),
#   (4, 1),
#   (36, 1),
#   (429, 1),
#   (43, 1),
#   (5, 1),
#   (614, 1),
#   (166, 1),
#   (93, 1),
#   (35, 1),
#   (54, 1),
#   (21, 1),
#   (66, 1),
#   (300, 1),
#   (372, 1),
#   (83, 1),
#   (51, 1),
#   (279, 1),
#   (163, 1),
#   (285, 1),
#   (28, 1),
#   (78, 1)],
#  'bb': [(146, 1),
#   (541, 1),
#   (1, 1),
#   (600, 1),
#   (331, 1),
#   (222, 1),
#   (75, 1),
#   (423, 1),
#   (144, 1),
#   (747, 1),
#   (747, 1),
#   (6, 1),
#   (137, 1)],
#  'beacon': [(1357, 1), (175, 1), (1571, 1)],
#  'beanstalk': [(305, 1), (1607, 1), (492, 1)],
#  'beast': [(45, 1),
#   (373, 1),
#   (655, 1),
#   (349, 1),
#   (30, 1),
#   (649, 1),
#   (232, 1),
#   (398, 1),
#   (1526, 1),
#   (243, 1),
#   (156, 1)],
#  'beastcaller': [(1246, 1), (782, 1)],
#  'beastmaster': [(2278, 1)],
#  'beasts': [(3417, 1)],
#  'beatdown': [(2193, 1)],
#  'beauty': [(624, 1), (2268, 1), (717, 1)],
#  'beckett': [(2182, 1)],
#  'beckoner': [(4339, 1)],
#  'bedevil': [(1174, 1)],
#  'beetle': [(337, 1), (3346, 1)],
#  'befuddle': [(713, 1), (278, 1), (316, 1), (24, 1), (1748, 1), (22, 1)],
#  'behemoth': [(974, 1), (142, 1), (427, 1), (458, 1), (2338, 1)],
#  'behold': [(1312, 1), (2850, 1)],
#  'beleren': [(382, 1), (28, 1), (72, 1), (3235, 1), (1208, 1), (6, 1)],
#  'belle': [(771, 1)],
#  'belligerent': [(1194, 1), (148, 1), (1578, 1), (252, 1)],
#  'bellower': [(2008, 1)],
#  'bellows': [(2710, 1), (1125, 1)],
#  'belltower': [(3170, 1), (788, 1)],
#  'beloved': [(178, 1), (4728, 1)],
#  'benalia': [(4266, 1)],
#  'benalish': [(2991, 1), (1587, 1), (106, 1)],
#  'benediction': [(2217, 1), (2143, 1)],
#  'benevolent': [(2252, 1), (339, 1), (161, 1), (266, 1)],
#  'benthic': [(592, 1), (1432, 1), (1261, 1)],
#  'benthid': [(1455, 1), (2918, 1)],
#  'berserkers': [(342, 1), (930, 1), (779, 1), (1198, 1)],
#  'beta': [(114, 1),
#   (27, 1),
#   (385, 1),
#   (766, 1),
#   (175, 1),
#   (125, 1),
#   (301, 1),
#   (211, 1),
#   (309, 1),
#   (225, 1),
#   (163, 1),
#   (357, 1),
#   (1101, 1),
#   (125, 1),
#   (103, 1),
#   (86, 1),
#   (92, 1),
#   (24, 1),
#   (20, 1),
#   (34, 1)],
#  'betrayal': [(4590, 1)],
#  'betrayers': [(2690, 1)],
#  'betrays': [(2145, 1), (1575, 1)],
#  'beyond': [(1312, 1), (2850, 1), (527, 1)],
#  'bioessence': [(3765, 1)],
#  'biogenic': [(1621, 1)],
#  'biomancer': [(592, 1)],
#  'bird': [(357, 1), (526, 1), (789, 1), (423, 1), (1799, 1), (721, 1)],
#  'birds': [(4, 1),
#   (69, 1),
#   (201, 1),
#   (894, 1),
#   (251, 1),
#   (32, 1),
#   (15, 1),
#   (196, 1),
#   (43, 1),
#   (555, 1),
#   (35, 1),
#   (143, 1),
#   (32, 1),
#   (103, 1),
#   (232, 1),
#   (281, 1),
#   (273, 1),
#   (234, 1),
#   (62, 1),
#   (372, 1),
#   (238, 1),
#   (64, 1),
#   (172, 1),
#   (197, 1),
#   (41, 1),
#   (160, 1)],
#  'birthing': [(1277, 1), (972, 1)],
#  'bishop': [(515, 1),
#   (127, 1),
#   (187, 1),
#   (2292, 1),
#   (46, 1),
#   (858, 1),
#   (610, 1)],
#  'bituminous': [(264, 1)],
#  'black': [(90, 1),
#   (216, 1),
#   (63, 1),
#   (717, 1),
#   (152, 1),
#   (777, 1),
#   (123, 1),
#   (35, 1),
#   (821, 1),
#   (88, 1),
#   (23, 1),
#   (15, 1),
#   (1266, 1),
#   (111, 1)],
#  'blackblade': [(1004, 1), (1210, 1)],
#  'blackcleave': [(2305, 1)],
#  'blacklance': [(1637, 1), (2542, 1)],
#  'blade': [(445, 1),
#   (1, 1),
#   (163, 1),
#   (150, 1),
#   (77, 1),
#   (94, 1),
#   (1056, 1),
#   (419, 1),
#   (1847, 1),
#   (348, 1),
#   (71, 1)],
#  'bladebrand': [(3, 1), (410, 1), (794, 1), (1782, 1), (1399, 1), (126, 1)],
#  'bladed': [(4314, 1), (502, 1)],
#  'bladetusk': [(27, 1), (3456, 1)],
#  'blanchwood': [(232, 1), (2222, 1)],
#  'blasphemous': [(1352, 1), (1664, 1)],
#  'blast': [(264, 1), (1612, 1), (228, 1), (683, 1), (900, 1), (41, 1)],
#  'blastfire': [(2424, 1), (635, 1)],
#  'blasting': [(827, 1)],
#  'blaze': [(2091, 1)],
#  'blazing': [(3267, 1), (211, 1), (1307, 1)],
#  'blessed': [(1575, 1), (1314, 1)],
#  'blessing': [(507, 1), (491, 1), (1029, 1), (1270, 1)],
#  'blessings': [(3847, 1), (487, 1)],
#  'blight': [(1690, 1), (27, 1), (631, 1), (41, 1), (235, 1), (1468, 1)],
#  'blightbeetle': [(690, 1), (1581, 1), (770, 1), (1096, 1), (155, 1), (56, 1)],
#  'blightcaster': [(704, 1), (1293, 1), (130, 1), (1672, 1)],
#  'blighted': [(1492, 1),
#   (186, 1),
#   (300, 1),
#   (231, 1),
#   (141, 1),
#   (270, 1),
#   (290, 1),
#   (381, 1),
#   (114, 1)],
#  'blindblast': [(3827, 1)],
#  'blinding': [(131, 1), (49, 1), (681, 1), (2558, 1)],
#  'blinkmoth': [(2226, 1), (2416, 1)],
#  'blistercoil': [(4043, 1)],
#  'blistering': [(3918, 1)],
#  'blisterpod': [(1748, 1), (125, 1)],
#  'blood': [(32, 1),
#   (60, 1),
#   (64, 1),
#   (71, 1),
#   (46, 1),
#   (69, 1),
#   (198, 1),
#   (162, 1),
#   (284, 1),
#   (46, 1),
#   (25, 1),
#   (64, 1),
#   (7, 1),
#   (10, 1),
#   (12, 1),
#   (122, 1),
#   (25, 1),
#   (187, 1),
#   (44, 1),
#   (43, 1),
#   (20, 1),
#   (60, 1),
#   (73, 1),
#   (82, 1),
#   (49, 1),
#   (37, 1),
#   (54, 1),
#   (105, 1),
#   (100, 1),
#   (288, 1),
#   (233, 1),
#   (10, 1),
#   (73, 1),
#   (146, 1),
#   (169, 1),
#   (74, 1),
#   (83, 1),
#   (22, 1),
#   (30, 1),
#   (82, 1),
#   (316, 1),
#   (120, 1),
#   (134, 1),
#   (17, 1),
#   (134, 1),
#   (14, 1),
#   (12, 1),
#   (20, 1),
#   (165, 1),
#   (229, 1),
#   (26, 1),
#   (103, 1),
#   (62, 1),
#   (140, 1)],
#  'bloodbond': [(1850, 1), (779, 1)],
#  'bloodbraid': [(4868, 1)],
#  'bloodbraided': [(4191, 1)],
#  'bloodcrazed': [(2160, 1), (1693, 1)],
#  'bloodfell': [(2124, 1), (438, 1), (1060, 1), (288, 1)],
#  'bloodflow': [(192, 1), (878, 1)],
#  'bloodghast': [(3546, 1)],
#  'bloodgift': [(2335, 1)],
#  'bloodhaze': [(1026, 1)],
#  'bloodhunter': [(2211, 1), (1792, 1)],
#  'bloodlord': [(99, 1),
#   (1369, 1),
#   (635, 1),
#   (534, 1),
#   (1033, 1),
#   (597, 1),
#   (22, 1),
#   (193, 1),
#   (73, 1),
#   (320, 1)],
#  'bloodrage': [(3025, 1), (1391, 1)],
#  'bloodseeker': [(812, 1), (3059, 1)],
#  'bloodsoaked': [(46, 1), (1393, 1), (833, 1), (2445, 1)],
#  'bloodstained': [(451, 1)],
#  'bloodthirsty': [(118, 1), (977, 1), (67, 1), (112, 1), (1593, 1), (419, 1)],
#  'bloodthrone': [(896, 1), (597, 1), (69, 1), (3217, 1)],
#  'bloom': [(211, 1), (4627, 1)],
#  'blooming': [(2706, 1)],
#  'blossoming': [(1117, 1), (363, 1), (755, 1), (1750, 1)],
#  'blow': [(221, 1)],
#  'blowfly': [(1040, 1)],
#  'blue': [(60, 1), (85, 1), (1731, 1), (1282, 1), (1584, 1)],
#  'blur': [(2864, 1), (1986, 1)],
#  'boar': [(27, 1),
#   (40, 1),
#   (676, 1),
#   (309, 1),
#   (970, 1),
#   (409, 1),
#   (725, 1),
#   (327, 1),
#   (167, 1),
#   (799, 1),
#   (192, 1),
#   (276, 1)],
#  'bodyguard': [(2252, 1), (766, 1)],
#  'bog': [(504, 1),
#   (396, 1),
#   (629, 1),
#   (121, 1),
#   (27, 1),
#   (363, 1),
#   (132, 1),
#   (575, 1),
#   (114, 1),
#   (29, 1),
#   (77, 1),
#   (114, 1),
#   (147, 1),
#   (97, 1),
#   (118, 1),
#   (829, 1),
#   (29, 1),
#   (150, 1),
#   (304, 1)],
#  'bogardan': [(2650, 1), (1256, 1), (455, 1)],
#  'bogbrew': [(556, 1), (2773, 1)],
#  'boggart': [(1758, 1), (1334, 1), (413, 1), (59, 1)],
#  'bogstomper': [(2510, 1), (1141, 1)],
#  'boiling': [(2518, 1), (1145, 1)],
#  'bolas': [(47, 1),
#   (590, 1),
#   (850, 1),
#   (15, 1),
#   (429, 1),
#   (281, 2),
#   (844, 1),
#   (31, 1),
#   (109, 1),
#   (196, 2),
#   (80, 1),
#   (1137, 1)],
#  'bold': [(182, 1)],
#  'bolt': [(191, 1),
#   (392, 1),
#   (49, 1),
#   (122, 1),
#   (276, 1),
#   (1394, 1),
#   (29, 1),
#   (38, 1),
#   (568, 1),
#   (621, 1),
#   (166, 1),
#   (317, 1),
#   (107, 1),
#   (95, 1),
#   (38, 1),
#   (68, 1),
#   (238, 1),
#   (14, 1),
#   (92, 1)],
#  'bomat': [(3753, 1)],
#  'bond': [(337, 1), (2610, 1), (193, 1), (158, 1), (385, 1)],
#  'bonded': [(1325, 1), (1296, 1)],
#  'bone': [(392, 1),
#   (180, 1),
#   (82, 1),
#   (1071, 1),
#   (97, 1),
#   (50, 1),
#   (53, 1),
#   (149, 1),
#   (211, 1),
#   (90, 1),
#   (2, 1),
#   (483, 1),
#   (112, 1),
#   (414, 1),
#   (492, 1),
#   (197, 1),
#   (151, 1),
#   (250, 1),
#   (89, 1),
#   (108, 1)],
#  'boneclad': [(124, 1), (717, 1), (2350, 1), (575, 1), (1096, 1)],
#  'bonecrusher': [(4820, 1), (59, 1)],
#  'bones': [(227, 1), (1301, 1), (43, 1), (868, 1), (1669, 1), (414, 1)],
#  'bonescythe': [(678, 1), (1074, 1), (700, 1)],
#  'bonfire': [(4170, 1), (600, 1)],
#  'bontu': [(470, 1), (4266, 1)],
#  'book': [(122, 1), (1622, 1), (1236, 1)],
#  'boon': [(4566, 1)],
#  'boonweaver': [(1551, 1), (1918, 1)],
#  'booster': [(2614, 1)],
#  'border': [(1646, 1), (3073, 1)],
#  'borderland': [(85, 1), (682, 1), (421, 1), (548, 1), (963, 1), (236, 1)],
#  'boreal': [(862, 1), (448, 1), (2511, 1), (121, 1), (890, 1)],
#  'born': [(1235, 1), (241, 1), (429, 1), (76, 1), (1511, 1), (532, 1)],
#  'boros': [(2842, 1)],
#  'borrower': [(3311, 1), (940, 1)],
#  'boseiju': [(4350, 1)],
#  'boss': [(717, 1)],
#  'botanical': [(1667, 1)],
#  'bottle': [(2565, 1)],
#  'bottomless': [(1093, 1)],
#  'bound': [(1324, 1)],
#  'bounding': [(420, 1), (1429, 1)],
#  'boundless': [(1243, 1), (235, 1), (1025, 1), (2260, 1)],
#  'bountiful': [(462, 1), (697, 1), (26, 1), (81, 1), (2606, 1), (723, 1)],
#  'bounty': [(1006, 1)],
#  'bower': [(1968, 1), (1274, 1)],
#  'box': [(1212, 1), (504, 1)],
#  'bracers': [(4314, 1), (502, 1)],
#  'brains': [(2768, 1), (12, 1)],
#  'bramble': [(3332, 1), (896, 1)],
#  'bramblecrush': [(1941, 1), (2158, 1)],
#  'bramblefort': [(1550, 1)],
#  'bramblewood': [(3556, 1)],
#  'brass': [(2182, 1), (371, 1), (655, 1), (822, 1), (49, 1), (343, 1)],
#  'brassclaw': [(57, 1), (3746, 1), (867, 1)],
#  'brave': [(2581, 1), (1969, 1)],
#  'brawl': [(771, 1), (638, 1), (1384, 1)],
#  'brawler': [(28, 1), (772, 1), (513, 1), (1089, 1), (1002, 1), (972, 1)],
#  'brawn': [(863, 1), (3961, 1)],
#  'brazen': [(3311, 1), (940, 1)],
#  'breaker': [(2061, 1), (267, 1), (560, 1), (955, 1)],
#  'breaking': [(962, 1), (1867, 1), (510, 1), (474, 1)],
#  'briarpack': [(2546, 1), (1055, 1)],
#  'bribery': [(1436, 1), (95, 1), (216, 1), (2358, 1)],
#  'bridge': [(700, 1), (510, 1), (75, 1), (695, 1), (1338, 1)],
#  'briefing': [(3839, 1)],
#  'brightwood': [(214, 1), (805, 1), (1381, 1), (2306, 1)],
#  'brilliant': [(217, 1), (1781, 1)],
#  'brimaz': [(799, 1)],
#  'brimstone': [(3808, 1)],
#  'brindle': [(67, 1), (676, 1), (309, 1), (970, 1), (409, 1), (1219, 1)],
#  'brineborn': [(97, 1), (708, 1), (2029, 1), (181, 1)],
#  'bring': [(314, 1), (708, 1), (759, 1)],
#  'brink': [(2610, 1), (2051, 1)],
#  'bristling': [(3156, 1), (1485, 1), (276, 1)],
#  'brittle': [(2932, 1), (795, 1)],
#  'broken': [(1986, 1)],
#  'broker': [(1651, 1), (241, 1), (1009, 1), (326, 1)],
#  'brontodon': [(2340, 1)],
#  'brood': [(848, 1),
#   (992, 1),
#   (21, 1),
#   (1073, 1),
#   (306, 1),
#   (767, 1),
#   (676, 1)],
#  'broodhunter': [(2776, 1), (94, 1)],
#  'broom': [(4169, 1)],
#  'brought': [(1136, 1), (466, 1), (941, 1), (1106, 1), (303, 1)],
#  'browbeat': [(2868, 1), (420, 1)],
#  'bruiser': [(2299, 1)],
#  'bruna': [(1681, 1), (1196, 1)],
#  'brushland': [(607, 1),
#   (21, 1),
#   (83, 1),
#   (294, 1),
#   (504, 1),
#   (255, 1),
#   (70, 1),
#   (119, 1),
#   (238, 1),
#   (290, 1),
#   (112, 1),
#   (259, 1),
#   (465, 1),
#   (377, 1),
#   (90, 1),
#   (813, 1),
#   (242, 1)],
#  'brutal': [(906, 1), (3920, 1)],
#  'brutality': [(3078, 1)],
#  'brutalizer': [(387, 1), (2023, 1), (1939, 1)],
#  'brute': [(1758, 1), (1334, 1), (413, 1), (59, 1)],
#  'bubbling': [(175, 1), (1275, 1)],
#  'buccaneer': [(56, 1), (1499, 1)],
#  'builder': [(2027, 1), (1270, 1)],
#  'bully': [(1593, 1), (1337, 1)],
#  'burden': [(36, 1), (4822, 1)],
#  'burglar': [(540, 1), (162, 1), (284, 1), (135, 1), (2023, 1), (938, 1)],
#  'buried': [(51, 1), (1471, 1), (2032, 1), (419, 1), (809, 1)],
#  'burn': [(2658, 1), (1168, 1)],
#  'burning': [(122, 1),
#   (277, 1),
#   (494, 1),
#   (226, 1),
#   (625, 1),
#   (501, 1),
#   (1, 1),
#   (576, 1),
#   (470, 1),
#   (121, 1),
#   (500, 1),
#   (479, 1),
#   (394, 1)],
#  'burst': [(416, 1), (1518, 1)],
#  'bushwhacker': [(250, 1), (4445, 1)],
#  'but': [(2000, 1), (970, 1), (1069, 1)],
#  'butcher': [(747, 1), (825, 1), (289, 1), (1073, 1), (593, 1), (1310, 1)],
#  'buy': [(1212, 1)],
#  'by': [(386, 1), (501, 1), (1215, 1), (1467, 1)],
#  'cabal': [(550, 1),
#   (121, 1),
#   (568, 1),
#   (171, 1),
#   (47, 1),
#   (1084, 1),
#   (318, 1),
#   (865, 1)],
#  'cabin': [(162, 1)],
#  'cage': [(1984, 1), (1544, 1), (608, 1)],
#  'caged': [(83, 1)],
#  'cagemail': [(3464, 1), (181, 1)],
#  'calamity': [(3040, 1)],
#  'calculated': [(2775, 1), (1448, 1)],
#  'call': [(212, 1),
#   (217, 1),
#   (153, 1),
#   (228, 1),
#   (369, 1),
#   (205, 1),
#   (75, 1),
#   (562, 1),
#   (166, 1),
#   (952, 1),
#   (100, 1),
#   (324, 1),
#   (252, 1),
#   (162, 1),
#   (451, 1),
#   (237, 1),
#   (110, 1),
#   (130, 1),
#   (17, 1)],
#  'caller': [(578, 1),
#   (15, 1),
#   (1363, 1),
#   (1461, 1),
#   (134, 1),
#   (404, 1),
#   (685, 1),
#   (249, 1)],
#  'calling': [(1474, 1),
#   (447, 1),
#   (3, 1),
#   (130, 1),
#   (934, 1),
#   (643, 1),
#   (268, 1)],
#  'canal': [(2349, 1)],
#  'cancel': [(43, 1),
#   (264, 1),
#   (26, 1),
#   (497, 1),
#   (577, 1),
#   (379, 1),
#   (495, 1),
#   (50, 1),
#   (479, 1),
#   (225, 1),
#   (704, 1),
#   (120, 1),
#   (16, 1),
#   (117, 1),
#   (328, 1)],
#  'candelabra': [(712, 1)],
#  'canker': [(138, 1), (956, 1)],
#  'cannon': [(1741, 1)],
#  'canopy': [(933, 1), (435, 1), (747, 1), (1475, 1), (1312, 1)],
#  'canyon': [(3415, 1)],
#  'cao': [(4342, 2)],
#  'capashen': [(2922, 1), (388, 1)],
#  'capricious': [(262, 1), (2135, 1)],
#  'captain': [(59, 1),
#   (99, 1),
#   (424, 1),
#   (51, 1),
#   (380, 1),
#   (52, 1),
#   (567, 1),
#   (143, 1),
#   (246, 1),
#   (135, 1),
#   (98, 1),
#   (432, 1),
#   (51, 1),
#   (1114, 1),
#   (1013, 1)],
#  'captivating': [(84, 1), (70, 1), (159, 1), (140, 1), (1154, 1), (222, 1)],
#  'carah': [(182, 1)],
#  'carapace': [(2616, 1)],
#  'caretaker': [(1939, 1), (148, 1), (1060, 1)],
#  'carnage': [(483, 1), (1650, 1), (2082, 1)],
#  'carnivorous': [(4500, 1), (156, 1)],
#  'carriage': [(2976, 1)],
#  'carrion': [(2286, 1), (1604, 1), (77, 1), (155, 1), (616, 1)],
#  'cartouche': [(176, 1), (877, 1), (542, 1), (2268, 1), (926, 1)],
#  'carver': [(1888, 1), (641, 1)],
#  'caryatid': [(444, 1)],
#  'casket': [(15, 1), (1976, 1), (804, 1)],
#  'cast': [(3265, 1)],
#  'castaway': [(3984, 1)],
#  'castigate': [(3604, 1)],
#  'castle': [(1494, 1),
#   (227, 1),
#   (117, 1),
#   (156, 1),
#   (216, 1),
#   (415, 1),
#   (158, 1),
#   (144, 1),
#   (307, 1),
#   (178, 1)],
#  'casualties': [(4800, 1)],
#  'cat': [(2845, 1), (149, 1), (27, 1), (99, 1), (192, 1), (1133, 1)],
#  'cataclysmic': [(3697, 1)],
#  'catacomb': [(1087, 1), (1145, 1)],
#  'catacombs': [(4261, 1)],
#  'catalyst': [(926, 1), (271, 1)],
#  'cataract': [(1678, 1), (1232, 1)],
#  'caterpillar': [(919, 1), (213, 1)],
#  'cathar': [(1901, 1), (1386, 1)],
#  'cathars': [(2533, 1), (1583, 1)],
#  'cathedral': [(1675, 1), (1364, 1), (596, 1), (895, 1), (402, 1)],
#  'cauldron': [(151, 1),
#   (24, 1),
#   (736, 1),
#   (195, 1),
#   (111, 1),
#   (233, 1),
#   (617, 1),
#   (1522, 1),
#   (385, 1),
#   (409, 1)],
#  'caustic': [(256, 1), (463, 1), (200, 1), (213, 1)],
#  'cavalier': [(193, 1),
#   (36, 1),
#   (143, 1),
#   (105, 1),
#   (92, 1),
#   (291, 1),
#   (127, 1),
#   (174, 1),
#   (10, 1),
#   (151, 1),
#   (52, 1),
#   (428, 1),
#   (62, 1),
#   (42, 1),
#   (27, 1),
#   (146, 1),
#   (143, 1),
#   (152, 1),
#   (405, 1),
#   (51, 1),
#   (179, 1),
#   (178, 1),
#   (72, 1),
#   (81, 1),
#   (613, 1),
#   (29, 1),
#   (116, 1),
#   (5, 1),
#   (446, 1),
#   (129, 1),
#   (1, 1),
#   (8, 1)],
#  'cavalry': [(38, 1), (257, 1)],
#  'cavern': [(258, 1), (1377, 1), (2452, 1)],
#  'caves': [(324, 1),
#   (195, 1),
#   (448, 1),
#   (1157, 1),
#   (438, 1),
#   (89, 1),
#   (971, 1),
#   (288, 1),
#   (908, 1)],
#  'ceaseless': [(196, 1)],
#  'celebrant': [(1012, 1)],
#  'celestial': [(294, 1),
#   (462, 1),
#   (312, 1),
#   (512, 1),
#   (311, 1),
#   (112, 1),
#   (840, 1),
#   (616, 1),
#   (31, 1),
#   (279, 1),
#   (37, 1),
#   (781, 1)],
#  'cemetery': [(661, 1), (982, 1), (1155, 1), (670, 1), (697, 1), (696, 1)],
#  'cenobite': [(2064, 1)],
#  'centaur': [(1080, 1), (951, 1)],
#  'cephalid': [(168, 1), (356, 1), (309, 1), (853, 1), (2659, 1)],
#  'ceratops': [(1286, 1), (1128, 1), (1098, 1)],
#  'cerulean': [(2679, 1), (2222, 1)],
#  'cetavolver': [(1126, 1), (2819, 1)],
#  'chain': [(1139, 1), (2946, 1)],
#  'chainer': [(3971, 1)],
#  'chainwhirler': [(4077, 1)],
#  'chamber': [(115, 1)],
#  'champion': [(969, 1),
#   (284, 1),
#   (236, 1),
#   (48, 1),
#   (7, 1),
#   (581, 1),
#   (648, 1),
#   (1626, 1),
#   (139, 1),
#   (264, 1)],
#  'champions': [(500, 1), (138, 1), (3070, 1), (436, 1)],
#  'champs': [(3556, 1), (121, 1)],
#  'chancellor': [(3428, 1)],
#  'chandra': [(207, 1),
#   (13, 1),
#   (84, 1),
#   (72, 1),
#   (83, 1),
#   (20, 1),
#   (273, 1),
#   (129, 1),
#   (53, 1),
#   (65, 1),
#   (26, 1),
#   (199, 1),
#   (170, 1),
#   (26, 1),
#   (95, 1),
#   (89, 1),
#   (88, 1),
#   (7, 1),
#   (54, 1),
#   (10, 1),
#   (5, 1),
#   (182, 1),
#   (7, 1),
#   (73, 1),
#   (86, 1),
#   (31, 1),
#   (72, 1),
#   (142, 1),
#   (243, 1),
#   (92, 1),
#   (21, 1),
#   (54, 1),
#   (10, 1),
#   (11, 1),
#   (149, 1),
#   (59, 1),
#   (115, 1),
#   (7, 1),
#   (72, 1),
#   (129, 1),
#   (14, 1),
#   (48, 1),
#   (26, 1),
#   (172, 1),
#   (17, 1),
#   (20, 1),
#   (155, 1),
#   (6, 1),
#   (17, 1),
#   (259, 1),
#   (103, 1),
#   (281, 1),
#   (26, 1),
#   (6, 1),
#   (90, 1),
#   (258, 1),
#   (64, 1)],
#  'change': [(385, 1),
#   (39, 1),
#   (1417, 1),
#   (22, 1),
#   (915, 1),
#   (248, 1),
#   (380, 1),
#   (979, 1)],
#  'chant': [(3597, 1)],
#  'chaos': [(579, 1),
#   (84, 1),
#   (78, 1),
#   (514, 1),
#   (291, 1),
#   (15, 1),
#   (96, 1),
#   (700, 1),
#   (159, 1),
#   (145, 1),
#   (556, 1),
#   (623, 1),
#   (204, 1),
#   (27, 1),
#   (489, 1),
#   (305, 1)],
#  'chapel': [(267, 1), (1092, 1)],
#  'charge': [(3309, 1)],
#  'charging': [(240, 1), (1646, 1), (1709, 1), (1276, 1)],
#  'charm': [(699, 1), (1280, 1), (863, 1)],
#  'charmed': [(1184, 1)],
#  'charming': [(2004, 1), (1848, 1), (238, 1), (687, 1)],
#  'chasm': [(2574, 1), (263, 1), (703, 1), (608, 1)],
#  'chastise': [(303, 1), (1586, 1)],
#  'chemister': [(2382, 1)],
#  'chief': [(471, 1), (908, 1), (581, 1), (1388, 1)],
#  'chieftain': [(3978, 1)],
#  'child': [(1054, 1),
#   (715, 1),
#   (3, 1),
#   (53, 1),
#   (370, 1),
#   (661, 1),
#   (257, 1),
#   (696, 1),
#   (1034, 1)],
#  'chittering': [(4309, 1)],
#  'cho': [(4200, 1)],
#  'choke': [(268, 1), (2836, 1), (511, 1)],
#  'chord': [(1474, 1),
#   (447, 1),
#   (3, 1),
#   (130, 1),
#   (934, 1),
#   (643, 1),
#   (268, 1)],
#  'chosen': [(2577, 1), (1414, 1)],
#  'chromatic': [(1481, 1), (851, 1)],
#  'chromium': [(177, 1), (1984, 1), (888, 1), (1123, 1)],
#  'chronicles': [(542, 1)],
#  'chronomaton': [(1340, 1), (3138, 1)],
#  'chronostutter': [(2521, 1), (9, 1)],
#  'chulane': [(2296, 1)],
#  'cinder': [(171, 1), (1371, 1), (926, 1), (261, 1), (2059, 1)],
#  'circle': [(60, 1),
#   (619, 1),
#   (600, 1),
#   (415, 1),
#   (565, 1),
#   (148, 1),
#   (751, 1),
#   (509, 1),
#   (339, 1)],
#  'citadel': [(637, 1), (1294, 1)],
#  'city': [(2553, 1), (655, 1), (822, 1), (49, 1), (343, 1)],
#  'civic': [(1665, 1)],
#  'clackbridge': [(11, 1), (2968, 1)],
#  'clad': [(10, 1), (1208, 1), (1585, 1), (553, 1), (1534, 1)],
#  'clade': [(3517, 1)],
#  'claim': [(2007, 1), (864, 1)],
#  'clancaller': [(3243, 1)],
#  'claustrophobia': [(3790, 1)],
#  'claw': [(3467, 1)],
#  'claws': [(933, 1), (3969, 1)],
#  'cleansing': [(1240, 1), (584, 1), (1884, 1), (154, 1)],
#  'clear': [(1465, 1), (274, 1)],
#  'clearing': [(794, 1)],
#  'cleaver': [(3629, 1), (542, 1)],
#  'cliffhaven': [(3537, 1)],
#  'cliffs': [(279, 1), (2026, 1)],
#  'clifftop': [(3202, 1)],
#  'cloak': [(901, 1)],
#  'cloaked': [(164, 1), (653, 1), (260, 1), (728, 1)],
#  'clock': [(2527, 1), (553, 1), (85, 1), (136, 1), (269, 1)],
#  'clockwork': [(1639, 1), (2537, 1)],
#  'clone': [(723, 1),
#   (305, 1),
#   (546, 1),
#   (127, 1),
#   (243, 1),
#   (312, 1),
#   (371, 1)],
#  'closed': [(230, 1), (501, 1), (257, 1), (3159, 1), (710, 1)],
#  'closet': [(367, 1), (490, 1)],
#  'cloudblazer': [(982, 1)],
#  'cloudkin': [(882, 1), (467, 1), (761, 1)],
#  'clouds': [(510, 1), (831, 1)],
#  'cloudshift': [(562, 1), (921, 1), (754, 1), (1539, 1)],
#  'clover': [(584, 1)],
#  'coast': [(929, 1)],
#  'coastal': [(2684, 1)],
#  'coat': [(223, 1),
#   (601, 1),
#   (89, 1),
#   (358, 1),
#   (133, 1),
#   (353, 1),
#   (82, 1),
#   (232, 1),
#   (602, 1),
#   (903, 1),
#   (136, 1),
#   (519, 1)],
#  'coffers': [(2859, 1)],
#  'coffin': [(328, 1)],
#  'cohort': [(811, 1)],
#  'coil': [(2080, 1)],
#  'coiling': [(3750, 1)],
#  'coldsnap': [(1347, 1), (1330, 1), (1627, 1)],
#  'coliseum': [(833, 1)],
#  'collected': [(2177, 1), (1467, 1)],
#  'collective': [(1048, 1), (2030, 1)],
#  'collector': [(1518, 1), (2502, 1)],
#  'colonnade': [(294, 1)],
#  'colossal': [(522, 1), (2402, 1), (340, 1)],
#  'colossodon': [(3479, 1)],
#  'colossus': [(320, 1), (550, 1), (2223, 1), (352, 1)],
#  'combat': [(1043, 1)],
#  'combustible': [(486, 1)],
#  'combustion': [(1897, 1), (786, 1), (935, 1)],
#  'comics': [(1876, 1), (1323, 1), (1346, 1)],
#  'command': [(49, 1),
#   (47, 1),
#   (235, 1),
#   (561, 1),
#   (241, 1),
#   (32, 1),
#   (67, 1),
#   (168, 1),
#   (779, 1),
#   (282, 1),
#   (67, 1),
#   (231, 1),
#   (64, 1),
#   (3, 1),
#   (238, 1),
#   (360, 1),
#   (563, 1),
#   (234, 1),
#   (54, 1),
#   (43, 1),
#   (19, 1),
#   (87, 1),
#   (250, 1),
#   (30, 1)],
#  'commander': [(248, 1),
#   (5, 1),
#   (26, 1),
#   (47, 1),
#   (287, 1),
#   (52, 1),
#   (65, 1),
#   (10, 1),
#   (117, 1),
#   (52, 1),
#   (111, 1),
#   (95, 1),
#   (39, 1),
#   (107, 1),
#   (57, 1),
#   (217, 1),
#   (42, 1),
#   (35, 1),
#   (2, 1),
#   (16, 1),
#   (12, 1),
#   (103, 1),
#   (83, 1),
#   (92, 1),
#   (164, 1),
#   (10, 1),
#   (41, 1),
#   (9, 1),
#   (18, 2),
#   (128, 1),
#   (64, 1),
#   (35, 1),
#   (54, 1),
#   (79, 1),
#   (165, 1),
#   (167, 1),
#   (197, 2),
#   (75, 1),
#   (55, 1),
#   (9, 1),
#   (178, 1),
#   (54, 1),
#   (72, 1),
#   (16, 1),
#   (7, 1),
#   (271, 1),
#   (124, 1),
#   (334, 1),
#   (66, 1),
#   (376, 1)],
#  'company': [(2177, 1), (1467, 1)],
#  'compliance': [(1379, 1)],
#  'components': [(205, 1), (4384, 1)],
#  'compulsion': [(1223, 1)],
#  'concealed': [(3206, 1)],
#  'conclave': [(4705, 1)],
#  'conditions': [(2774, 1), (1573, 1)],
#  'conduit': [(1547, 1), (1181, 1)],
#  'cone': [(571, 1), (1400, 1), (2216, 1), (274, 1), (101, 1)],
#  'conflux': [(282, 1), (3166, 1)],
#  'confrontation': [(3581, 1)],
#  'congregate': [(2882, 1), (2000, 1)],
#  'conifer': [(2126, 1)],
#  'conjurer': [(367, 1), (490, 1)],
#  'connections': [(1659, 1)],
#  'connoisseur': [(192, 1), (878, 1)],
#  'consecrate': [(537, 1),
#   (38, 1),
#   (80, 1),
#   (46, 1),
#   (428, 1),
#   (305, 1),
#   (99, 1),
#   (736, 1),
#   (286, 1),
#   (189, 1),
#   (697, 1),
#   (172, 1),
#   (201, 1),
#   (135, 1),
#   (127, 1),
#   (31, 1),
#   (412, 1),
#   (50, 1),
#   (256, 1)],
#  'constable': [(524, 1), (3821, 1)],
#  'constrictor': [(589, 1)],
#  'construct': [(1325, 1), (1296, 1)],
#  'consul': [(807, 1)],
#  'consume': [(981, 1), (993, 1)],
#  'consuming': [(3791, 1)],
#  'contempt': [(1163, 1)],
#  'contender': [(1015, 1),
#   (717, 1),
#   (231, 1),
#   (601, 1),
#   (69, 1),
#   (100, 1),
#   (151, 1),
#   (444, 1),
#   (102, 1),
#   (387, 1),
#   (724, 1),
#   (288, 1)],
#  'control': [(253, 1),
#   (276, 1),
#   (36, 1),
#   (84, 1),
#   (314, 1),
#   (772, 1),
#   (489, 1),
#   (1859, 1),
#   (37, 1),
#   (417, 1),
#   (36, 1)],
#  'convention': [(975, 1)],
#  'convincing': [(228, 1), (1514, 1)],
#  'copper': [(1486, 1),
#   (752, 1),
#   (273, 1),
#   (314, 1),
#   (60, 1),
#   (121, 1),
#   (297, 1),
#   (33, 1),
#   (320, 1),
#   (1055, 1)],
#  'copperline': [(2639, 1)],
#  'copter': [(1443, 1)],
#  'core': [(0, 1),
#   (22, 1),
#   (8, 1),
#   (11, 1),
#   (15, 1),
#   (3, 1),
#   (2, 1),
#   (17, 1),
#   (9, 1),
#   (25, 1),
#   (4, 1),
#   (8, 1),
#   (16, 1),
#   (34, 1),
#   (21, 1),
#   (29, 1),
#   (7, 1),
#   (6, 1),
#   (76, 1),
#   (22, 1),
#   (4, 1),
#   (17, 1),
#   (19, 1),
#   (6, 1),
#   (19, 1),
#   (9, 1),
#   (2, 1),
#   (2, 1),
#   (15, 1),
#   (13, 1),
#   (12, 1),
#   (24, 1),
#   (8, 1),
#   (7, 1),
#   (36, 1),
#   (20, 1),
#   (18, 1),
#   (4, 1),
#   (29, 1),
#   (18, 1),
#   (30, 1),
#   (5, 1),
#   (14, 1),
#   (4, 1),
#   (20, 1),
#   (38, 1),
#   (31, 1),
#   (21, 1),
#   (13, 1),
#   (13, 1),
#   (2, 1),
#   (18, 1),
#   (3, 1),
#   (20, 1),
#   (13, 1),
#   (6, 1),
#   (14, 1),
#   (34, 1),
#   (67, 1),
#   (6, 1),
#   (8, 1),
#   (39, 1),
#   (15, 1),
#   (21, 1),
#   (23, 1),
#   (6, 1),
#   (11, 1),
#   (9, 1),
#   (34, 1),
#   (16, 1),
#   (6, 1),
#   (27, 1),
#   (20, 1),
#   (45, 1),
#   (5, 1),
#   (12, 1),
#   (7, 1),
#   (14, 1),
#   (6, 1),
#   (19, 1),
#   (2, 1),
#   (15, 1),
#   (13, 1),
#   (1, 1),
#   (9, 1),
#   (16, 1),
#   (44, 1),
#   (36, 1),
#   (14, 1),
#   (19, 1),
#   (27, 1),
#   (25, 1),
#   (2, 1),
#   (32, 1),
#   (9, 1),
#   (29, 1),
#   (26, 1),
#   (20, 1),
#   (1, 1),
#   (13, 1),
#   (25, 1),
#   (20, 1),
#   (23, 1),
#   (8, 1),
#   (41, 1),
#   (4, 1),
#   (58, 1),
#   (42, 1),
#   (37, 1),
#   (5, 1),
#   (2, 1),
#   (34, 1),
#   (46, 1),
#   (11, 1),
#   (19, 1),
#   (35, 1),
#   (14, 1),
#   (30, 1),
#   (16, 1),
# ...
#   (16, 1),
#   (16, 1),
#   (21, 1),
#   (15, 1),
#   (30, 1),
#   (10, 1),
#   (7, 1),
#   (12, 1),
#   (5, 1),
#   (20, 1),
#   (36, 1),
#   (19, 1),
#   (30, 1),
#   (19, 1),
#   (14, 1),
#   (2, 1),
#   (7, 1),
#   (14, 1),
#   (27, 1),
#   (44, 1),
#   (9, 1),
#   (5, 1),
#   (18, 1),
#   (20, 1),
#   (1, 1),
#   (12, 1),
#   (45, 1),
#   (4, 1),
#   (6, 1),
#   (8, 1),
#   (37, 1),
#   (4, 1),
#   (11, 1),
#   (20, 1),
#   (15, 1),
#   (37, 1),
#   (2, 1),
#   (34, 1),
#   (9, 1),
#   (16, 1),
#   (2, 1),
#   (65, 1),
#   (27, 1),
#   (2, 1),
#   (61, 1),
#   (1, 1),
#   (14, 1),
#   (16, 1),
#   (49, 1),
#   (9, 1),
#   (16, 1),
#   (1, 1),
#   (18, 1),
#   (33, 1),
#   (2, 1),
#   (50, 1),
#   (11, 1),
#   (26, 1),
#   (3, 1),
#   (28, 1),
#   (11, 1),
#   (7, 1),
#   (29, 1),
#   (7, 1),
#   (22, 1),
#   (12, 1),
#   (11, 1),
#   (21, 1),
#   (11, 1),
#   (16, 1),
#   (40, 1),
#   (15, 1),
#   (18, 1),
#   (7, 1),
#   (24, 1),
#   (4, 1),
#   (17, 1),
#   (4, 1),
#   (85, 1),
#   (39, 1),
#   (4, 1),
#   (8, 1),
#   (83, 1),
#   (8, 1),
#   (29, 1),
#   (52, 1),
#   (22, 1),
#   (6, 1),
#   (64, 1),
#   (8, 1),
#   (16, 1),
#   (56, 1),
#   (6, 1),
#   (32, 1),
#   (2, 1),
#   (5, 1),
#   (4, 1),
#   (11, 1),
#   (12, 1),
#   (6, 1),
#   (1, 1),
#   (14, 1),
#   (15, 1),
#   (1, 1),
#   (5, 1),
#   (12, 1),
#   (22, 1),
#   (19, 1),
#   (7, 1),
#   (36, 1),
#   (24, 1),
#   (5, 1),
#   (2, 1),
#   (10, 1),
#   (14, 1),
#   (12, 1),
#   (6, 1),
#   (4, 1),
#   (25, 1),
#   (1, 1),
#   (26, 1),
#   (30, 1),
#   (12, 1),
#   (14, 1),
#   (15, 1),
#   (52, 1),
#   (17, 1),
#   (38, 1),
#   (70, 1),
#   (8, 1),
#   (12, 1),
#   (49, 1),
#   (41, 1),
#   (5, 1)],
#  'corpse': [(1066, 1), (619, 1), (454, 1), (1012, 1)],
#  'corridor': [(68, 1)],
#  'cottage': [(3990, 1)],
#  'counselor': [(4181, 1)],
#  'counterspell': [(25, 1),
#   (188, 1),
#   (317, 1),
#   (161, 1),
#   (325, 1),
#   (455, 1),
#   (144, 1),
#   (116, 1),
#   (86, 1),
#   (147, 1),
#   (263, 1),
#   (229, 1),
#   (376, 1),
#   (350, 1),
#   (163, 1),
#   (437, 1),
#   (36, 1),
#   (194, 1),
#   (607, 1),
#   (209, 1),
#   (50, 1)],
#  'courier': [(3753, 1)],
#  'courser': [(3439, 1)],
#  'courtly': [(1462, 1), (861, 1)],
#  'courtyard': [(3206, 1)],
#  'covetous': [(4682, 1)],
#  'cow': [(1055, 1), (2881, 1)],
#  'cower': [(680, 1), (697, 1)],
#  'cowl': [(2982, 1)],
#  'crafty': [(547, 1), (3868, 1)],
#  'crag': [(3524, 1)],
#  'crasher': [(1943, 1), (923, 1), (678, 1)],
#  'crashing': [(1905, 1), (1290, 1)],
#  'craterhoof': [(2001, 1)],
#  'craterize': [(558, 1), (2716, 1)],
#  'crazed': [(4229, 1)],
#  'creator': [(1785, 1)],
#  'creature': [(2947, 1)],
#  'creeper': [(3332, 1), (896, 1)],
#  'creeperhulk': [(3126, 1)],
#  'creeping': [(2370, 1), (15, 1), (776, 1), (849, 1)],
#  'crimson': [(2899, 1), (1643, 1)],
#  'crippling': [(1690, 1), (2402, 1)],
#  'crocodile': [(1759, 1)],
#  'crop': [(966, 1), (1870, 1)],
#  'crow': [(3967, 1), (155, 1)],
#  'crowns': [(554, 1), (340, 1), (658, 1), (1585, 1)],
#  'crucible': [(497, 1),
#   (134, 1),
#   (102, 1),
#   (184, 1),
#   (469, 1),
#   (87, 1),
#   (378, 1),
#   (323, 1),
#   (142, 1),
#   (767, 1),
#   (259, 1),
#   (363, 1),
#   (446, 1),
#   (341, 1)],
#  'cruel': [(1012, 1)],
#  'cruelties': [(942, 1)],
#  'crumbs': [(3043, 1)],
#  'crusade': [(2533, 1), (1583, 1)],
#  'crusader': [(914, 1), (45, 1), (1076, 1), (82, 1), (2422, 1)],
#  'crush': [(1589, 1), (421, 1), (1152, 1), (137, 1), (445, 1)],
#  'crusher': [(293, 1), (887, 1), (1670, 1), (553, 1)],
#  'crypt': [(3205, 1), (636, 1), (287, 1)],
#  'cryptbreaker': [(3071, 1)],
#  'cryptic': [(2651, 1)],
#  'crystal': [(1972, 1)],
#  'cube': [(2721, 1)],
#  'cudgel': [(714, 1)],
#  'culling': [(218, 1), (805, 1)],
#  'cunning': [(3984, 1)],
#  'cur': [(1066, 1)],
#  'curious': [(936, 1), (871, 1)],
#  'curse': [(1612, 1)],
#  'cursed': [(29, 1),
#   (464, 1),
#   (1090, 1),
#   (141, 1),
#   (948, 1),
#   (172, 1),
#   (1703, 1),
#   (108, 1)],
#  'cutthroat': [(97, 1), (708, 1), (2029, 1), (181, 1)],
#  'cyclopean': [(255, 1), (1833, 1), (587, 1)],
#  'daen': [(3231, 1)],
#  'dagger': [(3307, 1)],
#  'dais': [(218, 1), (805, 1)],
#  'damned': [(4170, 1), (600, 1)],
#  'dance': [(104, 1), (377, 1)],
#  'dancer': [(379, 1), (271, 1), (497, 1), (3594, 1)],
#  'daring': [(2632, 1)],
#  'dark': [(19, 1),
#   (272, 1),
#   (401, 1),
#   (213, 1),
#   (60, 1),
#   (139, 1),
#   (179, 1),
#   (187, 1),
#   (40, 1),
#   (201, 1),
#   (71, 1),
#   (32, 1),
#   (116, 1),
#   (295, 1),
#   (610, 1),
#   (91, 1),
#   (182, 1),
#   (97, 1),
#   (2, 1),
#   (6, 1),
#   (134, 1),
#   (10, 1),
#   (151, 1),
#   (211, 1),
#   (349, 1),
#   (391, 1),
#   (474, 1)],
#  'darkslick': [(4773, 1)],
#  'darksteel': [(320, 1),
#   (550, 1),
#   (809, 1),
#   (99, 1),
#   (866, 1),
#   (793, 1),
#   (147, 1),
#   (302, 1),
#   (53, 1),
#   (355, 1),
#   (113, 1)],
#  'dasher': [(2572, 1)],
#  'dauntless': [(4692, 1)],
#  'davriel': [(4531, 1), (62, 1)],
#  'dawn': [(120, 1),
#   (357, 1),
#   (207, 1),
#   (90, 1),
#   (53, 1),
#   (334, 1),
#   (633, 1),
#   (285, 1),
#   (1124, 1),
#   (137, 1),
#   (2, 1),
#   (395, 1),
#   (204, 1),
#   (41, 1),
#   (121, 1)],
#  'dawnbringer': [(979, 1)],
#  'dawns': [(335, 1)],
#  'day': [(560, 1), (42, 1), (1058, 1), (129, 1)],
#  'daya': [(2493, 1)],
#  'dead': [(5, 1),
#   (19, 1),
#   (29, 1),
#   (1, 1),
#   (79, 1),
#   (359, 1),
#   (323, 1),
#   (3, 1),
#   (92, 1),
#   (180, 1),
#   (68, 1),
#   (51, 1),
#   (783, 1),
#   (309, 1),
#   (661, 1),
#   (186, 1),
#   (366, 1),
#   (383, 1),
#   (82, 1),
#   (211, 1),
#   (274, 1),
#   (173, 1),
#   (32, 1),
#   (75, 1)],
#  'deadbridge': [(3597, 1)],
#  'deadly': [(3233, 1)],
#  'deafening': [(3263, 1), (680, 1)],
#  'dealer': [(1874, 1), (2842, 1)],
#  'death': [(386, 1),
#   (155, 1),
#   (181, 1),
#   (307, 1),
#   (176, 1),
#   (118, 1),
#   (1235, 1),
#   (1011, 1),
#   (1121, 1),
#   (133, 1)],
#  'deathbringer': [(3740, 1)],
#  'deathgrip': [(3927, 1)],
#  'deathless': [(3956, 1)],
#  'deathrite': [(3273, 1), (202, 1), (1369, 1)],
#  'debtors': [(336, 1), (384, 1), (2094, 1)],
#  'decay': [(241, 1), (1438, 1), (317, 1), (877, 1), (432, 1)],
#  'deceit': [(4406, 1)],
#  'deceiver': [(47, 1)],
#  'decimate': [(2854, 1)],
#  'decimator': [(1037, 1)],
#  'deck': [(673, 1), (318, 1), (434, 1), (1146, 1), (1020, 1), (590, 1)],
#  'decks': [(309, 1), (4127, 1), (69, 1), (32, 1), (47, 1), (271, 1)],
#  'declaration': [(2011, 1)],
#  'decree': [(535, 1),
#   (2352, 1),
#   (1223, 1),
#   (70, 1),
#   (141, 1),
#   (118, 1),
#   (70, 1),
#   (17, 1)],
#  'deep': [(260, 1), (690, 1), (20, 1), (275, 1), (908, 1)],
#  'defense': [(555, 1), (953, 1), (611, 1), (363, 1), (1121, 1), (92, 1)],
#  'defiance': [(1048, 1), (1952, 1), (115, 1)],
#  'defiant': [(844, 1), (80, 1), (259, 1)],
#  'defiled': [(686, 1), (3134, 1)],
#  'defiler': [(681, 1), (2567, 1)],
#  'delif': [(571, 1), (3616, 1), (274, 1), (101, 1)],
#  'delta': [(1098, 1)],
#  'delver': [(2398, 1), (289, 1), (1474, 1)],
#  'dementia': [(351, 1), (1084, 1)],
#  'demon': [(2335, 1), (878, 1), (762, 1)],
#  'demonic': [(141, 1),
#   (171, 1),
#   (613, 1),
#   (1264, 1),
#   (290, 1),
#   (1217, 1),
#   (335, 1)],
#  'den': [(2855, 1)],
#  'depravity': [(4299, 1)],
#  'depths': [(757, 1), (2056, 1), (67, 1), (949, 1), (967, 1)],
#  'deputy': [(2702, 1)],
#  'descendants': [(1291, 1)],
#  'desecrated': [(1270, 1), (509, 1), (780, 1), (1595, 1)],
#  'desert': [(1733, 1)],
#  'desertion': [(1845, 1),
#   (428, 1),
#   (274, 1),
#   (1334, 1),
#   (223, 1),
#   (346, 1),
#   (153, 1)],
#  'desolation': [(1708, 1)],
#  'despark': [(4065, 1)],
#  'destiny': [(2048, 1), (780, 1), (315, 1), (278, 1), (959, 1)],
#  'destructive': [(1553, 1)],
#  'detention': [(234, 1), (1386, 1), (1082, 1)],
#  'devastation': [(560, 1), (1229, 1), (1307, 1), (789, 1), (840, 1)],
#  'devotion': [(2120, 1), (926, 1)],
#  'devout': [(2887, 1), (1434, 1)],
#  'diabolic': [(750, 1), (3120, 1)],
#  'diamond': [(41, 1),
#   (1186, 1),
#   (1116, 1),
#   (86, 1),
#   (97, 1),
#   (395, 1),
#   (78, 1),
#   (262, 1),
#   (410, 1),
#   (946, 1),
#   (45, 1)],
#  'diaochan': [(624, 1), (2268, 1), (717, 1)],
#  'didn': [(3779, 1)],
#  'diffusion': [(4115, 1)],
#  'digger': [(1553, 1)],
#  'dignitary': [(4791, 1)],
#  'dimir': [(1201, 1), (1187, 1), (190, 1)],
#  'dingus': [(608, 1), (781, 1), (473, 1), (2737, 1)],
#  'dinosaur': [(393, 1)],
#  'dire': [(1702, 1), (717, 1), (297, 1)],
#  'diregraf': [(3093, 1)],
#  'disallow': [(3605, 1)],
#  'disaster': [(2610, 1), (2051, 1)],
#  'discerning': [(1256, 1)],
#  'discipline': [(194, 1), (841, 1), (2263, 1)],
#  'discordant': [(4336, 1)],
#  'disenchant': [(30, 1), (272, 1)],
#  'disfigure': [(4468, 1)],
#  'disintegrate': [(952, 1),
#   (879, 1),
#   (50, 1),
#   (12, 1),
#   (590, 1),
#   (303, 1),
#   (592, 1),
#   (320, 1)],
#  'disk': [(2083, 1), (2707, 1)],
#  'dismember': [(3785, 1)],
#  'dismissal': [(2775, 1), (1448, 1)],
#  'dispel': [(3241, 1)],
#  'dispute': [(1010, 1)],
#  'disrupting': [(626, 1), (1216, 1), (1890, 1), (1179, 1)],
#  'dissension': [(1350, 1)],
#  'distinguished': [(2841, 1)],
#  'diva': [(4771, 1)],
#  'divination': [(1946, 1), (1124, 1)],
#  'divine': [(98, 1)],
#  'djinn': [(37, 1),
#   (69, 1),
#   (1039, 1),
#   (434, 1),
#   (39, 1),
#   (472, 1),
#   (41, 1),
#   (665, 1),
#   (200, 1),
#   (178, 1),
#   (754, 1),
#   (396, 1),
#   (372, 1)],
#  'dominance': [(121, 1)],
#  'dominaria': [(1290, 1), (252, 1)],
#  'doom': [(755, 1), (1631, 1), (948, 1), (1366, 1)],
#  'doomed': [(185, 1), (878, 1)],
#  'doomsayer': [(3357, 1)],
#  'doomsday': [(1056, 1), (917, 1)],
#  'doran': [(4286, 1)],
#  'doubling': [(2721, 1)],
#  'dovescape': [(994, 1), (2529, 1)],
#  'dovin': [(1735, 1), (358, 1), (319, 1), (1150, 1)],
#  'down': [(221, 1)],
#  'downfall': [(4628, 1)],
#  'dragon': [(26, 1),
#   (163, 1),
#   (59, 1),
#   (110, 1),
#   (102, 1),
#   (306, 1),
#   (71, 1),
#   (205, 1),
#   (387, 1),
#   (58, 1),
#   (49, 1),
#   (286, 1),
#   (49, 1),
#   (307, 1),
#   (53, 1),
#   (32, 1),
#   (85, 1),
#   (27, 1),
#   (68, 1),
#   (120, 1),
#   (33, 1),
#   (220, 1),
#   (44, 1),
#   (58, 1),
#   (143, 1),
#   (562, 1),
#   (63, 1),
#   (607, 1),
#   (53, 1),
#   (188, 1),
#   (46, 1),
#   (34, 1),
#   (24, 1),
#   (77, 1)],
#  'dragonfire': [(2334, 1)],
#  'dragonlair': [(1084, 1), (728, 1), (105, 1), (619, 1), (1759, 1), (58, 1)],
#  'dragons': [(2447, 1)],
#  'dragonspeaker': [(1008, 1)],
#  'dragoon': [(2057, 1)],
#  'drake': [(167, 1), (2478, 1), (34, 1), (2222, 1)],
#  'drakuseth': [(400, 1), (332, 1), (117, 1)],
#  'drawbridge': [(3195, 1)],
#  'drawn': [(0, 1), (1204, 1), (2526, 1)],
#  'dread': [(925, 1), (700, 1), (1422, 1), (323, 1)],
#  'dreadbore': [(777, 1), (2550, 1), (1518, 1)],
#  'dreadful': [(352, 1)],
#  'dreadhorde': [(2826, 1), (2014, 1)],
#  'dreadknight': [(4923, 1)],
#  'dreadmaw': [(3264, 1)],
#  'dream': [(1952, 1), (417, 1)],
#  'dreamer': [(1546, 1), (598, 1)],
#  'dreams': [(0, 1), (1204, 1), (2526, 1)],
#  'dreamstone': [(3762, 1)],
#  'drillmaster': [(38, 1), (257, 1)],
#  'droiture': [(709, 1)],
#  'drown': [(3933, 1)],
#  'drowned': [(1087, 1), (1145, 1)],
#  'druid': [(355, 1),
#   (453, 1),
#   (274, 1),
#   (172, 1),
#   (1073, 1),
#   (1226, 1),
#   (1298, 1)],
#  'drum': [(3558, 1)],
#  'dryad': [(2753, 1), (665, 1), (26, 1), (98, 1), (944, 1)],
#  'duel': [(309, 1), (4127, 1), (69, 1), (32, 1), (47, 1), (271, 1)],
#  'duels': [(1652, 1), (215, 1), (619, 1)],
#  'dummy': [(1496, 1)],
#  'dungeon': [(1432, 1), (834, 1), (1445, 1)],
#  'duplicant': [(285, 1),
#   (180, 1),
#   (204, 1),
#   (103, 1),
#   (182, 1),
#   (1214, 1),
#   (708, 1),
#   (111, 1),
#   (309, 1),
#   (459, 1)],
#  'dusk': [(2220, 1)],
#  'dust': [(461, 1)],
#  'dwarven': [(1100, 1), (570, 1), (21, 1), (1647, 1)],
#  'dwarves': [(3220, 1)],
#  'dwynen': [(2307, 1), (924, 1)],
#  'eagle': [(485, 1), (692, 1), (10, 1), (130, 1), (324, 1)],
#  'earth': [(2246, 1), (272, 1), (1145, 1), (1123, 1)],
#  'earthquake': [(1360, 1)],
#  'eater': [(315, 1), (2054, 1), (952, 1)],
#  'ebon': [(566, 1), (1291, 1), (704, 1), (891, 1), (1365, 1)],
#  'ebony': [(1962, 1), (97, 1), (890, 1)],
#  'echo': [(2364, 1)],
#  'echoing': [(1679, 1)],
#  'edge': [(1069, 1)],
#  'edgewall': [(3726, 1)],
#  'edict': [(750, 1), (3221, 1)],
#  'edificer': [(1221, 1)],
#  'edition': [(374, 1),
#   (191, 1),
#   (245, 1),
#   (91, 1),
#   (116, 1),
#   (39, 1),
#   (530, 1),
#   (17, 1),
#   (260, 1),
#   (278, 1),
#   (204, 1),
#   (84, 1),
#   (96, 1),
#   (261, 1),
#   (107, 1),
#   (102, 1),
#   (31, 1),
#   (108, 1),
#   (244, 1),
#   (68, 1),
#   (127, 1),
#   (176, 1),
#   (37, 1),
#   (33, 1),
#   (12, 1),
#   (345, 1),
#   (454, 1)],
#  'edric': [(1523, 1), (1567, 1), (19, 1), (450, 1), (131, 1)],
#  'eesha': [(1828, 1)],
#  'effigy': [(2932, 1), (795, 1)],
#  'efreet': [(262, 1), (2135, 1)],
#  'egg': [(608, 1), (76, 1), (631, 1), (74, 1), (473, 1), (2737, 1)],
#  'ego': [(3168, 1)],
#  'eidolon': [(3780, 1)],
#  'elder': [(260, 1),
#   (172, 1),
#   (518, 1),
#   (20, 1),
#   (275, 1),
#   (908, 1),
#   (2645, 1)],
#  'elders': [(4330, 1)],
#  'elderspell': [(2791, 1)],
#  'eldraine': [(2633, 1)],
#  'eldrazi': [(293, 1),
#   (1815, 1),
#   (28, 1),
#   (1394, 1),
#   (190, 1),
#   (42, 1),
#   (285, 1)],
#  'eldritch': [(103, 1),
#   (589, 1),
#   (239, 1),
#   (1126, 1),
#   (412, 1),
#   (438, 1),
#   (380, 1),
#   (826, 1)],
#  'electrickery': [(1382, 1)],
#  'electrodominance': [(4370, 1)],
#  'elemental': [(282, 1),
#   (74, 1),
#   (506, 1),
#   (64, 1),
#   (201, 1),
#   (70, 1),
#   (113, 1),
#   (566, 1),
#   (165, 1),
#   (1099, 1),
#   (63, 1),
#   (77, 1),
#   (185, 1),
#   (126, 1),
#   (230, 1),
#   (47, 1),
#   (74, 1),
#   (5, 1),
#   (71, 1),
#   (401, 1),
#   (197, 1),
#   (197, 1),
#   (19, 1)],
#  'elements': [(2581, 1), (1969, 1)],
#  'elenda': [(2220, 1)],
#  'elenora': [(1256, 1)],
#  'elesh': [(2064, 1)],
#  'elf': [(2502, 1), (1767, 1), (599, 1)],
#  'elite': [(103, 1), (764, 1), (413, 1), (356, 1), (671, 1)],
#  'elves': [(689, 1), (742, 1), (298, 1), (536, 1), (302, 1), (1059, 1)],
#  'elvish': [(425, 1),
#   (731, 1),
#   (158, 1),
#   (62, 1),
#   (122, 1),
#   (717, 1),
#   (109, 1),
#   (175, 1),
#   (112, 1),
#   (632, 1),
#   (155, 1),
#   (259, 1),
#   (239, 1),
#   (498, 1),
#   (352, 1)],
#  'ember': [(2580, 1), (1652, 1)],
#  'embercat': [(304, 1), (577, 1), (1890, 1), (1027, 1)],
#  'embercleave': [(1740, 1), (2496, 1)],
#  'embereth': [(523, 1), (1471, 1), (558, 1), (860, 1), (200, 1), (131, 1)],
#  'emblem': [(757, 1)],
#  'embodiment': [(1730, 1), (1527, 1), (120, 1)],
#  'emerald': [(489, 1),
#   (1031, 1),
#   (367, 1),
#   (131, 1),
#   (183, 1),
#   (712, 1),
#   (339, 1)],
#  'emeria': [(183, 1), (1076, 1)],
#  'emmara': [(1190, 1), (1406, 1)],
#  'empires': [(1624, 1), (966, 1)],
#  'empyrean': [(485, 1), (692, 1), (140, 1)],
#  'emrakul': [(2745, 1), (869, 1), (677, 1)],
#  'emry': [(2427, 1), (1532, 1), (914, 1)],
#  'encampment': [(1683, 1), (1546, 1)],
#  'enchanted': [(2976, 1)],
#  'enchantress': [(8, 1),
#   (178, 1),
#   (878, 1),
#   (294, 1),
#   (3160, 1),
#   (2, 1),
#   (78, 1)],
#  'encyclopedia': [(3757, 1), (584, 1)],
#  'end': [(81, 1), (489, 1), (82, 1), (2025, 1), (937, 1), (459, 1), (130, 1)],
#  'endurance': [(2840, 1), (912, 1)],
#  'energy': [(595, 1),
#   (549, 1),
#   (217, 1),
#   (258, 1),
#   (470, 1),
#   (517, 1),
#   (389, 1),
#   (216, 1)],
#  'enforcer': [(2601, 1), (35, 1), (907, 1)],
#  'engine': [(3334, 1)],
#  'engineer': [(471, 1), (247, 1), (838, 1), (370, 1), (34, 1), (1388, 1)],
#  'engulfing': [(441, 1)],
#  'enigmatic': [(1967, 1)],
#  'enlightened': [(2056, 1), (36, 1), (575, 1)],
#  'enlightenment': [(3849, 1)],
#  'ensnaring': [(700, 1), (510, 1), (75, 1), (695, 1)],
#  'ensoul': [(4375, 1)],
#  'entering': [(2829, 1), (510, 1)],
#  'entomber': [(4663, 1)],
#  'eons': [(2364, 1)],
#  'eos': [(2156, 1)],
#  'epic': [(3178, 1), (403, 1), (1047, 1)],
#  'epicure': [(1806, 1)],
#  'epiphany': [(1067, 1), (1881, 1), (35, 1), (1272, 1), (337, 1)],
#  'equilibrium': [(1649, 1)],
#  'erase': [(4912, 1)],
#  'erasure': [(1330, 1)],
#  'erebos': [(4224, 1)],
#  'erhnam': [(37, 1),
#   (69, 1),
#   (1039, 1),
#   (473, 1),
#   (472, 1),
#   (906, 1),
#   (178, 1),
#   (754, 1),
#   (396, 1),
#   (372, 1)],
#  'errant': [(4017, 1)],
#  'eruption': [(441, 1)],
#  'escape': [(813, 1), (3017, 1)],
#  'escort': [(4692, 1)],
#  'essence': [(806, 1), (2668, 1)],
#  'estate': [(1, 1), (4630, 1)],
#  'etchings': [(4304, 1)],
#  'eternal': [(120, 1),
#   (124, 1),
#   (226, 1),
#   (306, 1),
#   (187, 1),
#   (150, 1),
#   (711, 1),
#   (248, 1),
#   (109, 1),
#   (133, 1),
#   (348, 1),
#   (99, 1),
#   (225, 1),
#   (381, 1),
#   (122, 1),
#   (312, 1),
#   (89, 1),
#   (22, 1),
#   (48, 1),
#   (28, 1)],
#  'eternity': [(984, 1), (122, 1), (961, 1)],
#  'ethereal': [(1062, 1)],
#  'etherium': [(2277, 1), (597, 1), (1814, 1)],
#  'etrata': [(590, 1), (2129, 1), (1026, 1)],
#  'evacuation': [(134, 1), (188, 1), (766, 1), (949, 1), (2360, 1)],
#  'even': [(204, 1),
#   (119, 1),
#   (595, 1),
#   (126, 1),
#   (683, 1),
#   (117, 1),
#   (22, 1),
#   (136, 1),
#   (613, 1),
#   (152, 1),
#   (127, 1),
#   (168, 1),
#   (207, 1),
#   (126, 1),
#   (25, 1),
#   (137, 1),
#   (150, 1),
#   (131, 1),
#   (221, 1),
#   (529, 1),
#   (217, 1),
#   (115, 1)],
#  'eventide': [(2729, 1), (859, 1)],
#  'ever': [(113, 1), (444, 1), (1328, 1), (2839, 1)],
#  ...}

# %%
def int_to_vb_code(value):
    if value < (1 << 7):
        return bytearray([value + (1 << 7)])
    x = 7
    while((value>>(x+7)) > 0):
        x = x + 7
    return bytearray([value>>x]) + vb_code(value-((value>>x)<<x)) 

def vb_code_to_int(bytesarray):
    size = len(bytesarray)
    total = 0
    for (b, i) in [(bytesarray[i], i + 1) for i in range(len(bytesarray))]:
        total = total + (b << (7 * (size - i)))
    return total - (1 << 7)

# %%
def get_size(obj, seen=None):
    """Recursively finds size of objects"""
    size = sys.getsizeof(obj)
    if seen is None:
        seen = set()
    obj_id = id(obj)
    if obj_id in seen:
        return 0
    # Important mark as seen *before* entering recursion to gracefully handle
    # self-referential objects
    seen.add(obj_id)
    if isinstance(obj, dict):
        size += sum([get_size(v, seen) for v in obj.values()])
        size += sum([get_size(k, seen) for k in obj.keys()])
    elif hasattr(obj, '__dict__'):
        size += get_size(obj.__dict__, seen)
    elif hasattr(obj, '__iter__') and not isinstance(obj, (str, bytes, bytearray)):
        size += sum([get_size(i, seen) for i in obj])
    return size

# %%
def tf_compressed(lr, lf, lv, r, f, v):
    return int_to_vb_code(r)
get_size(create_inverse_index(tf_function)) - get_size(create_inverse_index(tf_compressed))
# Out:
# 1992833

# %%
compressed = create_inverse_index(tf_compressed)

# %%
def vb_code_to_int_array(bytearrays):
    array = []
    prev = 0
    cur = bytearray()
    for b in bytearrays:
        cur = cur + bytes([b])
        if b & (1 << 7):
            value = vb_code_to_int(cur)
            array.append(value - prev)
            cur = bytearray()
            prev = value
    return array
# Out:
# [901, 2672, 213, 844]

# %%
vb_code_to_int_array(compressed['10th'])
# Out:
# [901, 2672, 213, 844]
